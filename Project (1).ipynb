# %%
from google.colab import drive
drive.mount("/content/gdrive")
# %cd gdrive/MyDrive/Stroke

# !pip install nilearn
# !pip install monai
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# /content/gdrive/MyDrive/Stroke
# Requirement already satisfied: nilearn in /usr/local/lib/python3.7/dist-packages (0.9.1)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.7/dist-packages (from nilearn) (1.7.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from nilearn) (4.2.6)
# Requirement already satisfied: pandas>=1.0 in /usr/local/lib/python3.7/dist-packages (from nilearn) (1.3.5)
# Requirement already satisfied: joblib>=0.15 in /usr/local/lib/python3.7/dist-packages (from nilearn) (1.1.0)
# Requirement already satisfied: nibabel>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from nilearn) (3.0.2)
# Requirement already satisfied: requests>=2 in /usr/local/lib/python3.7/dist-packages (from nilearn) (2.23.0)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.7/dist-packages (from nilearn) (1.0.2)
# Requirement already satisfied: numpy>=1.18 in /usr/local/lib/python3.7/dist-packages (from nilearn) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0->nilearn) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0->nilearn) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=1.0->nilearn) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2->nilearn) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2->nilearn) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2->nilearn) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2->nilearn) (1.24.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22->nilearn) (3.1.0)
# Requirement already satisfied: monai in /usr/local/lib/python3.7/dist-packages (0.8.1)
# Requirement already satisfied: torch>=1.6 in /usr/local/lib/python3.7/dist-packages (from monai) (1.11.0+cu113)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from monai) (1.21.6)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.6->monai) (4.2.0)

# %%
# !ls
# Out:
# ehl_epoch0  ehl_epoch10  ehl_epoch15  ehl_epoch5  ISLES2016  ISLES2017

# %%
import os
from nilearn import plotting
from matplotlib import pyplot as plt
# %matplotlib inline
import numpy as np
import glob
import nibabel as nib
from nilearn import image

def get_sub_folders(folder):
    return [sub_folder for sub_folder in os.listdir(folder) if os.path.isdir(os.path.join(folder, sub_folder))]

def get_image_type_from_folder_name(folder_name):
    image_types = ['.MR_4DPWI', '.MR_ADC', '.MR_MTT', '.MR_rCBF', '.MR_rCBV', '.MR_Tmax', '.MR_TTP', '.OT']
    return next(image_type for image_type in image_types if image_type in folder_name)

def get_extension(filename):
    filename, extension = os.path.splitext(filename)
    return extension

def contrast_normalization(image, min_divisor=1e-3):
    mean = image.mean()
    std = image.std()
    if std < min_divisor:
        std = min_divisor
    return (image - mean) / std

def build_multimodal_image(image_list):
    shape = image_list[0].shape
    for image in image_list:
        assert image.shape == shape
    return np.stack(image_list).transpose((1, 2, 3, 0)).astype(np.float32)

# %%
TRAIN, TEST = 'TRAIN', 'TEST'
import nibabel as nib
import os
def read_and_process_data(input_dir, mode=TRAIN):
    # 4DPWI and ADC are raw data, the others are derived maps, OT is the expert segmentation
    # 4DPWI has a time dimension of 80 seconds (and already has the channel dimension added in)
    modes_to_use = ['.MR_ADC', '.MR_MTT', '.MR_rCBF', '.MR_rCBV', '.MR_Tmax', '.MR_TTP']
    data = {}
    
    for folder in get_sub_folders(input_dir):
        modality=[]
        _buffer = []
        data[folder] = {}
        for sub_folder in get_sub_folders(os.path.join(input_dir, folder)):
            image_type = get_image_type_from_folder_name(sub_folder)
            if image_type in modes_to_use:
                modality.append(sub_folder)
            if image_type == '.OT':
                path = os.path.join(input_dir, folder, sub_folder)
                filename = next(filename for filename in os.listdir(path) if get_extension(filename) == '.nii')
                path = os.path.join(path, filename)
                im = nib.load(path)
                image = im.get_fdata()
                data[folder]['ground_truth'] = image.astype(np.uint8)
            if image_type == '.MR_4DPWI':
                continue

        modality=sorted(modality)
        print(modality)
        #print(folder,modality)
        for s in modality:
            path = os.path.join(input_dir, folder, s)
            filename = next(filename for filename in os.listdir(path) if get_extension(filename) == '.nii')
            #print(folder,filename)
            path = os.path.join(path, filename)
            im = nib.load(path)
            image = im.get_fdata()
            _buffer.append(contrast_normalization(image))
            #_buffer.append(image)

        data[folder]['image'] = build_multimodal_image(_buffer)
        #if mode is TEST:
            #data[folder]['ground_truth'] = np.zeros(shape=shape)

    return data

train_image_data=read_and_process_data('ISLES2017/ISLES2017_Training/',mode=TRAIN)
# Out:
# ['VSD.Brain.XX.O.MR_ADC.128047', 'VSD.Brain.XX.O.MR_MTT.127230', 'VSD.Brain.XX.O.MR_TTP.127235', 'VSD.Brain.XX.O.MR_Tmax.127234', 'VSD.Brain.XX.O.MR_rCBF.127232', 'VSD.Brain.XX.O.MR_rCBV.127233']
# ['VSD.Brain.XX.O.MR_ADC.128049', 'VSD.Brain.XX.O.MR_MTT.127246', 'VSD.Brain.XX.O.MR_TTP.127251', 'VSD.Brain.XX.O.MR_Tmax.127250', 'VSD.Brain.XX.O.MR_rCBF.127248', 'VSD.Brain.XX.O.MR_rCBV.127249']
# ['VSD.Brain.XX.O.MR_ADC.128048', 'VSD.Brain.XX.O.MR_MTT.127238', 'VSD.Brain.XX.O.MR_TTP.127243', 'VSD.Brain.XX.O.MR_Tmax.127242', 'VSD.Brain.XX.O.MR_rCBF.127240', 'VSD.Brain.XX.O.MR_rCBV.127241']
# ['VSD.Brain.XX.O.MR_ADC.128020', 'VSD.Brain.XX.O.MR_MTT.127014', 'VSD.Brain.XX.O.MR_TTP.127019', 'VSD.Brain.XX.O.MR_Tmax.127018', 'VSD.Brain.XX.O.MR_rCBF.127016', 'VSD.Brain.XX.O.MR_rCBV.127017']
# ['VSD.Brain.XX.O.MR_ADC.128046', 'VSD.Brain.XX.O.MR_MTT.127222', 'VSD.Brain.XX.O.MR_TTP.127227', 'VSD.Brain.XX.O.MR_Tmax.127226', 'VSD.Brain.XX.O.MR_rCBF.127224', 'VSD.Brain.XX.O.MR_rCBV.127225']
# ['VSD.Brain.XX.O.MR_ADC.128039', 'VSD.Brain.XX.O.MR_MTT.127166', 'VSD.Brain.XX.O.MR_TTP.127171', 'VSD.Brain.XX.O.MR_Tmax.127170', 'VSD.Brain.XX.O.MR_rCBF.127168', 'VSD.Brain.XX.O.MR_rCBV.127169']
# ['SMIR.Brain.XX.O.MR_ADC.188888', 'SMIR.Brain.XX.O.MR_MTT.188889', 'SMIR.Brain.XX.O.MR_TTP.188894', 'SMIR.Brain.XX.O.MR_Tmax.188893', 'SMIR.Brain.XX.O.MR_rCBF.188891', 'SMIR.Brain.XX.O.MR_rCBV.188892']
# ['SMIR.Brain.XX.O.MR_ADC.188872', 'SMIR.Brain.XX.O.MR_MTT.188873', 'SMIR.Brain.XX.O.MR_TTP.188878', 'SMIR.Brain.XX.O.MR_Tmax.188877', 'SMIR.Brain.XX.O.MR_rCBF.188875', 'SMIR.Brain.XX.O.MR_rCBV.188876']
# ['SMIR.Brain.XX.O.MR_ADC.188880', 'SMIR.Brain.XX.O.MR_MTT.188881', 'SMIR.Brain.XX.O.MR_TTP.188886', 'SMIR.Brain.XX.O.MR_Tmax.188885', 'SMIR.Brain.XX.O.MR_rCBF.188883', 'SMIR.Brain.XX.O.MR_rCBV.188884']
# ['SMIR.Brain.XX.O.MR_ADC.188864', 'SMIR.Brain.XX.O.MR_MTT.188865', 'SMIR.Brain.XX.O.MR_TTP.188870', 'SMIR.Brain.XX.O.MR_Tmax.188869', 'SMIR.Brain.XX.O.MR_rCBF.188867', 'SMIR.Brain.XX.O.MR_rCBV.188868']
# ['VSD.Brain.XX.O.MR_ADC.128024', 'VSD.Brain.XX.O.MR_MTT.127046', 'VSD.Brain.XX.O.MR_TTP.127051', 'VSD.Brain.XX.O.MR_Tmax.127050', 'VSD.Brain.XX.O.MR_rCBF.127048', 'VSD.Brain.XX.O.MR_rCBV.127049']
# ['SMIR.Brain.XX.O.MR_ADC.188896', 'SMIR.Brain.XX.O.MR_MTT.188897', 'SMIR.Brain.XX.O.MR_TTP.188902', 'SMIR.Brain.XX.O.MR_Tmax.188901', 'SMIR.Brain.XX.O.MR_rCBF.188899', 'SMIR.Brain.XX.O.MR_rCBV.188900']
# ['VSD.Brain.XX.O.MR_ADC.128025', 'VSD.Brain.XX.O.MR_MTT.127054', 'VSD.Brain.XX.O.MR_TTP.127059', 'VSD.Brain.XX.O.MR_Tmax.127058', 'VSD.Brain.XX.O.MR_rCBF.127056', 'VSD.Brain.XX.O.MR_rCBV.127057']
# ['VSD.Brain.XX.O.MR_ADC.128033', 'VSD.Brain.XX.O.MR_MTT.127118', 'VSD.Brain.XX.O.MR_TTP.127123', 'VSD.Brain.XX.O.MR_Tmax.127122', 'VSD.Brain.XX.O.MR_rCBF.127120', 'VSD.Brain.XX.O.MR_rCBV.127121']
# ['VSD.Brain.XX.O.MR_ADC.128040', 'VSD.Brain.XX.O.MR_MTT.127174', 'VSD.Brain.XX.O.MR_TTP.127179', 'VSD.Brain.XX.O.MR_Tmax.127178', 'VSD.Brain.XX.O.MR_rCBF.127176', 'VSD.Brain.XX.O.MR_rCBV.127177']
# ['SMIR.Brain.XX.O.MR_ADC.188993', 'SMIR.Brain.XX.O.MR_MTT.188994', 'SMIR.Brain.XX.O.MR_TTP.188999', 'SMIR.Brain.XX.O.MR_Tmax.188998', 'SMIR.Brain.XX.O.MR_rCBF.188996', 'SMIR.Brain.XX.O.MR_rCBV.188997']
# ['VSD.Brain.XX.O.MR_ADC.128023', 'VSD.Brain.XX.O.MR_MTT.127038', 'VSD.Brain.XX.O.MR_TTP.127043', 'VSD.Brain.XX.O.MR_Tmax.127042', 'VSD.Brain.XX.O.MR_rCBF.127040', 'VSD.Brain.XX.O.MR_rCBV.127041']
# ['VSD.Brain.XX.O.MR_ADC.128026', 'VSD.Brain.XX.O.MR_MTT.127062', 'VSD.Brain.XX.O.MR_TTP.127067', 'VSD.Brain.XX.O.MR_Tmax.127066', 'VSD.Brain.XX.O.MR_rCBF.127064', 'VSD.Brain.XX.O.MR_rCBV.127065']
# ['VSD.Brain.XX.O.MR_ADC.128030', 'VSD.Brain.XX.O.MR_MTT.127094', 'VSD.Brain.XX.O.MR_TTP.127099', 'VSD.Brain.XX.O.MR_Tmax.127098', 'VSD.Brain.XX.O.MR_rCBF.127096', 'VSD.Brain.XX.O.MR_rCBV.127097']
# ['VSD.Brain.XX.O.MR_ADC.128045', 'VSD.Brain.XX.O.MR_MTT.127214', 'VSD.Brain.XX.O.MR_TTP.127219', 'VSD.Brain.XX.O.MR_Tmax.127218', 'VSD.Brain.XX.O.MR_rCBF.127216', 'VSD.Brain.XX.O.MR_rCBV.127217']
# ['VSD.Brain.XX.O.MR_ADC.128035', 'VSD.Brain.XX.O.MR_MTT.127134', 'VSD.Brain.XX.O.MR_TTP.127139', 'VSD.Brain.XX.O.MR_Tmax.127138', 'VSD.Brain.XX.O.MR_rCBF.127136', 'VSD.Brain.XX.O.MR_rCBV.127137']
# ['SMIR.Brain.XX.O.MR_ADC.188904', 'SMIR.Brain.XX.O.MR_MTT.188905', 'SMIR.Brain.XX.O.MR_TTP.188910', 'SMIR.Brain.XX.O.MR_Tmax.188909', 'SMIR.Brain.XX.O.MR_rCBF.188907', 'SMIR.Brain.XX.O.MR_rCBV.188908']
# ['VSD.Brain.XX.O.MR_ADC.128034', 'VSD.Brain.XX.O.MR_MTT.127126', 'VSD.Brain.XX.O.MR_TTP.127131', 'VSD.Brain.XX.O.MR_Tmax.127130', 'VSD.Brain.XX.O.MR_rCBF.127128', 'VSD.Brain.XX.O.MR_rCBV.127129']
# ['SMIR.Brain.XX.O.MR_ADC.188985', 'SMIR.Brain.XX.O.MR_MTT.188986', 'SMIR.Brain.XX.O.MR_TTP.188991', 'SMIR.Brain.XX.O.MR_Tmax.188990', 'SMIR.Brain.XX.O.MR_rCBF.188988', 'SMIR.Brain.XX.O.MR_rCBV.188989']
# ['SMIR.Brain.XX.O.MR_ADC.189001', 'SMIR.Brain.XX.O.MR_MTT.189002', 'SMIR.Brain.XX.O.MR_TTP.189007', 'SMIR.Brain.XX.O.MR_Tmax.189006', 'SMIR.Brain.XX.O.MR_rCBF.189004', 'SMIR.Brain.XX.O.MR_rCBV.189005']
# ['VSD.Brain.XX.O.MR_ADC.128044', 'VSD.Brain.XX.O.MR_MTT.127206', 'VSD.Brain.XX.O.MR_TTP.127211', 'VSD.Brain.XX.O.MR_Tmax.127210', 'VSD.Brain.XX.O.MR_rCBF.127208', 'VSD.Brain.XX.O.MR_rCBV.127209']
# ['VSD.Brain.XX.O.MR_ADC.128041', 'VSD.Brain.XX.O.MR_MTT.127182', 'VSD.Brain.XX.O.MR_TTP.127187', 'VSD.Brain.XX.O.MR_Tmax.127186', 'VSD.Brain.XX.O.MR_rCBF.127184', 'VSD.Brain.XX.O.MR_rCBV.127185']
# ['VSD.Brain.XX.O.MR_ADC.128042', 'VSD.Brain.XX.O.MR_MTT.127190', 'VSD.Brain.XX.O.MR_TTP.127195', 'VSD.Brain.XX.O.MR_Tmax.127194', 'VSD.Brain.XX.O.MR_rCBF.127192', 'VSD.Brain.XX.O.MR_rCBV.127193']
# ['SMIR.Brain.XX.O.MR_ADC.188920', 'SMIR.Brain.XX.O.MR_MTT.188921', 'SMIR.Brain.XX.O.MR_TTP.188926', 'SMIR.Brain.XX.O.MR_Tmax.188925', 'SMIR.Brain.XX.O.MR_rCBF.188923', 'SMIR.Brain.XX.O.MR_rCBV.188924']
# ['SMIR.Brain.XX.O.MR_ADC.188928', 'SMIR.Brain.XX.O.MR_MTT.188929', 'SMIR.Brain.XX.O.MR_TTP.188934', 'SMIR.Brain.XX.O.MR_Tmax.188933', 'SMIR.Brain.XX.O.MR_rCBF.188931', 'SMIR.Brain.XX.O.MR_rCBV.188932']
# ['VSD.Brain.XX.O.MR_ADC.128043', 'VSD.Brain.XX.O.MR_MTT.127198', 'VSD.Brain.XX.O.MR_TTP.127203', 'VSD.Brain.XX.O.MR_Tmax.127202', 'VSD.Brain.XX.O.MR_rCBF.127200', 'VSD.Brain.XX.O.MR_rCBV.127201']
# ['SMIR.Brain.XX.O.MR_ADC.188912', 'SMIR.Brain.XX.O.MR_MTT.188913', 'SMIR.Brain.XX.O.MR_TTP.188918', 'SMIR.Brain.XX.O.MR_Tmax.188917', 'SMIR.Brain.XX.O.MR_rCBF.188915', 'SMIR.Brain.XX.O.MR_rCBV.188916']
# ['SMIR.Brain.XX.O.MR_ADC.188957', 'SMIR.Brain.XX.O.MR_MTT.188971', 'SMIR.Brain.XX.O.MR_TTP.188976', 'SMIR.Brain.XX.O.MR_Tmax.188975', 'SMIR.Brain.XX.O.MR_rCBF.188973', 'SMIR.Brain.XX.O.MR_rCBV.188974']
# ['VSD.Brain.XX.O.MR_ADC.128021', 'VSD.Brain.XX.O.MR_MTT.127022', 'VSD.Brain.XX.O.MR_TTP.127027', 'VSD.Brain.XX.O.MR_Tmax.127026', 'VSD.Brain.XX.O.MR_rCBF.127024', 'VSD.Brain.XX.O.MR_rCBV.127025']
# ['VSD.Brain.XX.O.MR_ADC.128038', 'VSD.Brain.XX.O.MR_MTT.127158', 'VSD.Brain.XX.O.MR_TTP.127163', 'VSD.Brain.XX.O.MR_Tmax.127162', 'VSD.Brain.XX.O.MR_rCBF.127160', 'VSD.Brain.XX.O.MR_rCBV.127161']
# ['VSD.Brain.XX.O.MR_ADC.128032', 'VSD.Brain.XX.O.MR_MTT.127110', 'VSD.Brain.XX.O.MR_TTP.127115', 'VSD.Brain.XX.O.MR_Tmax.127114', 'VSD.Brain.XX.O.MR_rCBF.127112', 'VSD.Brain.XX.O.MR_rCBV.127113']
# ['VSD.Brain.XX.O.MR_ADC.128036', 'VSD.Brain.XX.O.MR_MTT.127142', 'VSD.Brain.XX.O.MR_TTP.127147', 'VSD.Brain.XX.O.MR_Tmax.127146', 'VSD.Brain.XX.O.MR_rCBF.127144', 'VSD.Brain.XX.O.MR_rCBV.127145']
# ['VSD.Brain.XX.O.MR_ADC.128029', 'VSD.Brain.XX.O.MR_MTT.127086', 'VSD.Brain.XX.O.MR_TTP.127091', 'VSD.Brain.XX.O.MR_Tmax.127090', 'VSD.Brain.XX.O.MR_rCBF.127088', 'VSD.Brain.XX.O.MR_rCBV.127089']
# ['VSD.Brain.XX.O.MR_ADC.128031', 'VSD.Brain.XX.O.MR_MTT.127102', 'VSD.Brain.XX.O.MR_TTP.127107', 'VSD.Brain.XX.O.MR_Tmax.127106', 'VSD.Brain.XX.O.MR_rCBF.127104', 'VSD.Brain.XX.O.MR_rCBV.127105']
# ['VSD.Brain.XX.O.MR_ADC.128027', 'VSD.Brain.XX.O.MR_MTT.127070', 'VSD.Brain.XX.O.MR_TTP.127075', 'VSD.Brain.XX.O.MR_Tmax.127074', 'VSD.Brain.XX.O.MR_rCBF.127072', 'VSD.Brain.XX.O.MR_rCBV.127073']
# ['VSD.Brain.XX.O.MR_ADC.128022', 'VSD.Brain.XX.O.MR_MTT.127030', 'VSD.Brain.XX.O.MR_TTP.127035', 'VSD.Brain.XX.O.MR_Tmax.127034', 'VSD.Brain.XX.O.MR_rCBF.127032', 'VSD.Brain.XX.O.MR_rCBV.127033']
# ['VSD.Brain.XX.O.MR_ADC.128028', 'VSD.Brain.XX.O.MR_MTT.127078', 'VSD.Brain.XX.O.MR_TTP.127083', 'VSD.Brain.XX.O.MR_Tmax.127082', 'VSD.Brain.XX.O.MR_rCBF.127080', 'VSD.Brain.XX.O.MR_rCBV.127081']
# ['VSD.Brain.XX.O.MR_ADC.128037', 'VSD.Brain.XX.O.MR_MTT.127150', 'VSD.Brain.XX.O.MR_TTP.127155', 'VSD.Brain.XX.O.MR_Tmax.127154', 'VSD.Brain.XX.O.MR_rCBF.127152', 'VSD.Brain.XX.O.MR_rCBV.127153']

# %%
a=train_image_data['training_20']['image'][:,:,:,:].reshape(-1)
from matplotlib.ticker import PercentFormatter



plt.hist(a, density=True)

plt.gca().yaxis.set_major_formatter(PercentFormatter(1))
plt.show()

print(np.percentile(a,0))
# Out:
# -0.7385354042053223

# %%
## preprocess image by 3d mask 

import torch
import numpy as np
torch.manual_seed(17)


def mask(modality):
  shape=modality.shape
  mask=modality>0
  mask=np.sum(mask,axis=3)>5
  indices=np.argwhere(mask==True)
  return list(set(indices[:,2]))

def crop(case):
  modality=case['image']
  gt=case['ground_truth']
  im_list=[]
  gt_list=[]
  slices=mask(modality)
  for i in slices:
    pic=modality[:,:,i,:]
    im_list.append(pic)
    gt_list.append(gt[:,:,i])

  return np.array(im_list),np.array(gt_list)


#demo=crop(train_image_data["training_19"])



ourdata = {}

count=1
for num in train_image_data:
  slices,target=crop(train_image_data[num])
  for i in range(len(slices)) :
    ourdata['train_'+str(count)]={}
    ourdata['train_'+str(count)]['image']=slices[i]
    ourdata['train_'+str(count)]['gt']=np.array(target[i])
    count+=1

# %%
alldata = {}

counter=1
for case in train_image_data:
  gt=train_image_data[case]['ground_truth']
  mod=train_image_data[case]['image']
  for i in range(gt.shape[2]) :
    alldata['train_'+str(counter)]={}
    #alldata['train_'+str(counter)]['image']=np.uint8(np.multiply(mod[:,:,i,:],1))
    alldata['train_'+str(counter)]['image']=mod[:,:,i,:]
    alldata['train_'+str(counter)]['gt']=np.uint8(gt[:,:,i])
    counter+=1

# %%
label_with_info=[]
for sample in alldata:
  label=alldata[sample]['gt']
  sum=np.sum(label)
  if sum>0:
    label_with_info.append(sample)
    

data_with_lesion=dict((k, alldata[k]) for k in label_with_info)

# %%
### create dataset
import os
from torchvision.io import read_image
import torch
from torch.utils.data import Dataset, DataLoader
from PIL import Image
import torchvision
from torchvision import datasets, transforms
from monai import transforms as mtransforms
import pandas as pd
import PIL
import cv2
from sklearn.model_selection import train_test_split


img_transforms = transforms.Compose([
    #transforms.ToPILImage(),
    #transforms.Resize((192,192)),
    transforms.ToTensor(),  
    mtransforms.ScaleIntensityRangePercentiles(0,100,0,1.0,relative=True),                          
    #transforms.ToTensor()
    ]
    #transforms.Normalize(mean, std)
    )



train_list=[]
gt_list=[]

for i in data_with_lesion:
  train_list.append(data_with_lesion[i]['image'])
  gt_list.append(data_with_lesion[i]['gt'])


validation_set_size = 0.2
 


class Strokedata(Dataset):
    def __init__(self, image, target, transform=img_transforms,train=True):
        self.train=train
        self.target = target
        self.transform=img_transforms
        self.train_img, self.validation_img,self.train_label,self.validation_label = train_test_split(image,target, test_size = validation_set_size, random_state = 5)

    def __len__(self):
        if self.train:
          length = len(self.train_img)
        else:
          length = len(self.validation_img)
        return length

    def __getitem__(self, idx):
      if self.train:
        img=self.train_img[idx]
        gt = self.train_label[idx]
      else:
        img=self.validation_img[idx]
        gt = self.validation_label[idx]

      
      img=cv2.resize(img, dsize=(192, 192), interpolation=cv2.INTER_LINEAR)
      gt = cv2.resize(gt, dsize=(192, 192), interpolation=cv2.INTER_NEAREST)

      if self.transform:
          x=[]
          for ch in range(img.shape[2]):
            x.append(self.transform(img[:,:,ch]))
          img_tfm = torch.cat(x)
        #if self.target_transform:

      sample = {'image': img_tfm, 'gt': gt}
      return sample
  

lesion_dataset_train=Strokedata(train_list,gt_list,transform=img_transforms,train=True)
lesion_dataset_validation=Strokedata(train_list,gt_list,transform=img_transforms,train=False)


train_loader = DataLoader(lesion_dataset_train, batch_size=2, shuffle=True)
validation_loader=DataLoader(lesion_dataset_validation, batch_size=2, shuffle=True)

print(len(train_loader))
print(len(validation_loader))
# Out:
# 146
# 37

# %%
for ith_batch, sample_batched in enumerate(train_loader):
    X_train = sample_batched['image']
    y_train = sample_batched['gt']
    plt.figure()
    plt.subplot(1,2,1)
    plt.axis("off")

    plt.imshow(X_train[0,3,:,:],cmap='gray')
    plt.subplot(1,2,2)
    plt.axis("off")

    plt.imshow(X_train[0,1,:,:],cmap='gray')
    if ith_batch==3:
      break

# %%
import monai
train_files=[{'image':img,'gt':gt} for img,gt in zip(train_list, gt_list)]


monai_transforms = mtransforms.Compose([
    mtransforms.ScaleIntensityRangePercentilesd(['image','gt'],0,100,0,255,clip=True),                              
    #mtransforms.CropForegroundd(keys=['image','gt'],source_key='image',margin=0,channel_indices=1),
    mtransforms.Resized(['image'],spatial_size=192,size_mode='longest'),                
    mtransforms.ToTensord(keys=['image','gt'])]
    #transforms.Normalize(mean, std)
    )

monai_ds=monai.data.Dataset(data=train_files,transform=monai_transforms)
monai_trainloader=monai.data.DataLoader(monai_ds,batch_size=1)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
###model

import torch
import torch.nn as nn
import torch.nn.functional as F

class Expand(nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self, x):
        return torch.unsqueeze(x, dim=0)

class Squeeze(nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self, x):
        return torch.squeeze(x, dim=1)

class SE_block(nn.Module):
    """[summary]
    
    Squeeze Excite block
    """
    def __init__(self, in_channels, ratio=16):
        super().__init__()
        self.avg_2d = F.adaptive_avg_pool2d
        self.dense_block = nn.Sequential(
            nn.Linear(in_channels, in_channels // ratio, bias=False),
            nn.ReLU(),
            nn.Linear(in_channels // ratio, in_channels, bias=False),
            nn.Sigmoid(),
        )

    def forward(self, x):
        filters = x.size(1)
        reshape_size = (x.size(0), 1, 1, filters)
        se = self.avg_2d(x, (1, 1))
        se = torch.reshape(se, reshape_size)
        se = self.dense_block(se)
        se = se.permute(0, 3, 1, 2)
        return x * se

class BN_block2d(nn.Module):
    """
        2-d batch-norm block
    """
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.bn_block = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(),
            nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU()
        )

    def forward(self, x):
        return self.bn_block(x)

class BN_block3d(nn.Module):
    """
        3-d batch-norm block
    """
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.bn_block = nn.Sequential(
            nn.Conv3d(in_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm3d(out_channels),
            nn.ReLU(),
            nn.Conv3d(out_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm3d(out_channels),
            nn.ReLU()
        )

    def forward(self, x):
        return self.bn_block(x)

class D_SE_Add(nn.Module):
    """
        D_SE_Add block
    """
    def __init__(self, in_channels, out_channels, mid_channels):
        super().__init__()
        
        self.conv3d_ = nn.Conv3d(in_channels, 1, kernel_size=1, padding=0)
        self.Squeeze = Squeeze()
        self.conv2d_ = nn.Conv2d(mid_channels, out_channels, kernel_size=3, padding=1)
        self.ReLU = nn.ReLU()
        
        self.SE_block = SE_block(in_channels)
        
        self.squeeze_block_3d = nn.Sequential(
            nn.Conv3d(in_channels, 1, kernel_size=1, padding=0),
            Squeeze(),
            nn.Conv2d(mid_channels, out_channels, kernel_size=3, padding=1),
            nn.ReLU(),
            SE_block(in_channels)
        )
        
    def forward(self, in_3d, in_2d):
        in_2d = self.SE_block(in_2d)
        in_3d = self.squeeze_block_3d(in_3d)

        return in_3d + in_2d

def up_block(in_channels, out_channels):
    return nn.Sequential(
        nn.Upsample(scale_factor=2, mode='nearest'),
        nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1),
        nn.ReLU()
    )




"""
    D-UNet: a dimension-fusion U shape network for chronic stroke lesion segmentation
    https://arxiv.org/pdf/1908.05104.pdf
"""


def weights_init_he(m):
    if isinstance(m, nn.Conv2d):
        torch.nn.init.kaiming_uniform_(m.weight)
        torch.nn.init.zeros_(m.bias)
    if isinstance(m, nn.Conv3d):
        torch.nn.init.kaiming_uniform_(m.weight)
        torch.nn.init.zeros_(m.bias)

class DUnet(nn.Module):
    def __init__(self, in_channels, weights_init = True):
        super().__init__()

        self.in_channels = in_channels
        in_channels_3d = 1
        
        self.Expand = Expand
        self.MaxPool3d = nn.MaxPool3d(kernel_size=2)
        self.MaxPool2d = nn.MaxPool2d(kernel_size=2)
        self.Dropout = nn.Dropout(0.3)
        
        # 3d down
        self.bn_3d_1 = BN_block3d(in_channels_3d, in_channels_3d * 32)
        #self.bn_3d_2 = BN_block3d(in_channels_3d * 32, in_channels_3d * 64)
        self.bn_3d_2 = BN_block3d(in_channels_3d * 32, in_channels_3d * 96)
        #self.bn_3d_3 = BN_block3d(in_channels_3d * 64, in_channels_3d * 128)
        self.bn_3d_3 = BN_block3d(in_channels_3d * 96, in_channels_3d * 192)
        
        # 2d down
        
        self.bn_2d_1 = BN_block2d(in_channels, in_channels * 8)

        self.bn_2d_2 = BN_block2d(in_channels * 8, in_channels * 16)
        #self.se_add_2 = D_SE_Add(in_channels * 16, in_channels * 16, 2)
        self.se_add_2 = D_SE_Add(in_channels * 16, in_channels * 16, 3)
        
        self.bn_2d_3 = BN_block2d(in_channels * 16, in_channels * 32)
        self.se_add_3 = D_SE_Add(in_channels * 32, in_channels * 32, 1)
        
        self.bn_2d_4 = BN_block2d(in_channels * 32, in_channels * 64)

        self.bn_2d_5 = BN_block2d(in_channels * 64, in_channels * 128)
        
        # up

        self.up_block_1 = up_block(in_channels * 128, in_channels * 64)
        self.bn_2d_6 = BN_block2d(in_channels * 128, in_channels * 64)
        
        self.up_block_2 = up_block(in_channels * 64, in_channels * 32)
        self.bn_2d_7 = BN_block2d(in_channels * 64, in_channels * 32)
        
        self.up_block_3 = up_block(in_channels * 32, in_channels * 16)
        self.bn_2d_8 = BN_block2d(in_channels * 32, in_channels * 16)
        
        self.up_block_4 = up_block(in_channels * 16, in_channels * 8)
        self.bn_2d_9 = BN_block2d(in_channels * 16, in_channels * 8)
        
        self.conv_10 = nn.Sequential(
            nn.Conv2d(in_channels * 8, 1, kernel_size=1, padding=0),
            nn.Sigmoid()
        )

        # He initialization stated in the original paper
        if weights_init:
            self.apply(weights_init_he)

    def forward(self, x):
        input3d = self.Expand()(x) # 1, batch_size, 4, 192, 192
        input3d = input3d.permute(1, 0, 2, 3, 4) # batch_size, 1, 4, 192, 192

        # 3d Stream
        conv3d1 = self.bn_3d_1(input3d)
        pool3d1 = self.MaxPool3d(conv3d1)

        conv3d2 = self.bn_3d_2(pool3d1)
        pool3d2 = self.MaxPool3d(conv3d2)

        conv3d3 = self.bn_3d_3(pool3d2)
        
        # 2d Encoding
        in_channels = self.in_channels

        conv1 = self.bn_2d_1(x)
        pool1 = self.MaxPool2d(conv1)

        conv2 = self.bn_2d_2(pool1)
        conv2 = self.se_add_2(conv3d2, conv2)
        pool2 = self.MaxPool2d(conv2)

        conv3 = self.bn_2d_3(pool2)
        conv3 = self.se_add_3(conv3d3, conv3)
        pool3 = self.MaxPool2d(conv3)

        conv4 = self.bn_2d_4(pool3)
        conv4 = self.Dropout(conv4)
        pool4 = self.MaxPool2d(conv4)

        conv5 = self.bn_2d_5(pool4)
        conv5 = self.Dropout(conv5)

        # Decoding

        up6 = self.up_block_1(conv5)
        merge6 = torch.cat(([conv4, up6]), 1)
        conv6 = self.bn_2d_6(merge6)

        up7 = self.up_block_2(conv6)
        merge7 = torch.cat(([conv3, up7]), 1)
        conv7 = self.bn_2d_7(merge7)

        up8 = self.up_block_3(conv7)
        merge8 = torch.cat(([conv2, up8]), 1)
        conv8 = self.bn_2d_8(merge8)

        up9 = self.up_block_4(conv8)
        merge9 = torch.cat(([conv1, up9]), 1)
        conv9 = self.bn_2d_9(merge9)

        conv10 = self.conv_10(conv9)

        return conv10

if __name__ == "__main__":

   model = DUnet(in_channels=6)
   model.to('cuda')

    #BATCH_SIZE = 1
    #input_batch = torch.Tensor(BATCH_SIZE, 6, 192, 192)
    #output_batch = model(input_batch)

    #print(output_batch.size()) # BATCH_SIZE, 1, 192, 192

# %%
##LOSS

class DiceBCELoss(nn.Module):
    def __init__(self, weight=None, size_average=True):
        super(DiceBCELoss, self).__init__()

    def forward(self, inputs, targets, smooth=1):
        
        #comment out if your model contains a sigmoid or equivalent activation layer
        #inputs = F.sigmoid(inputs)       
        
        #flatten label and prediction tensors
        inputs = inputs.view(-1)
        targets = targets.view(-1)
        
        intersection = (inputs * targets).sum()                            
        dice_loss = 1 - (2.*intersection + smooth)/(inputs.sum() + targets.sum() + smooth)  
        BCE = F.binary_cross_entropy(inputs, targets, reduction='mean')
        Dice_BCE = BCE + dice_loss
        
        return Dice_BCE
  

#criterion =DiceBCELoss()


#Focal
ALPHA = 1.1
GAMMA = 0.48

class FocalLoss(nn.Module):
    def __init__(self, weight=None, size_average=True):
        super(FocalLoss, self).__init__()

    def forward(self, inputs, targets, alpha=ALPHA, gamma=GAMMA, smooth=1):
        
        #comment out if your model contains a sigmoid or equivalent activation layer
        #inputs = F.sigmoid(inputs)       
        
        #flatten label and prediction tensors
        inputs = inputs.view(-1)
        targets = targets.view(-1)
        n=len(targets)
        
        #first compute binary cross-entropy 
        BCE = F.binary_cross_entropy(inputs, targets, reduction='mean')
        BCE_EXP = torch.exp(-BCE)
        focal_loss = alpha * (1-BCE_EXP)**gamma * BCE
                       
        return focal_loss

#DICE
class DiceLoss(nn.Module):
    def __init__(self, weight=None, size_average=True):
        super(DiceLoss, self).__init__()

    def forward(self, inputs, targets, smooth=1):
        
        #comment out if your model contains a sigmoid or equivalent activation layer
        #inputs = F.sigmoid(inputs)       
        
        #flatten label and prediction tensors
        inputs = inputs.view(-1)
        targets = targets.view(-1)
        
        intersection = (inputs * targets).sum()                            
        dice = (2.*intersection + smooth)/(inputs.sum() + targets.sum() + smooth)  
        
        #return 1 - dice
        return 1-dice


def ehl(y_pred,y_train):
  return FocalLoss()(y_pred,y_train)-torch.log(DiceLoss()(y_pred,y_train))

# %%
##optimizer
optimizer = torch.optim.Adam(model.parameters(), lr = 3*10**-4)

# %%
###Train loop
### Focal Loss function
epochs = 100


train_running_loss_history = []
validation_running_loss_history =[]
dice_coeff_focalfn=[]

for e in range(epochs):
  dice_loss=0.0
  train_running_loss = 0.0
  validation_running_loss = 0.0
  
  model.train()
  
  for ith_batch, sample_batched in enumerate(train_loader):
    X_train = sample_batched['image'].to('cuda')
    y_train = sample_batched['gt'].to('cuda')

    optimizer.zero_grad()
    y_pred = model(X_train)
   #out = (y_pred + 0.5).int().float()
    
    #loss = FocalLoss()(y_pred,y_train)/N-torch.log(DiceLoss()(y_pred,y_train))
    #loss = criterion(y_pred, y_train)
    loss = FocalLoss()(y_pred,y_train.float())
    loss.backward()
    optimizer.step()
    
    if ith_batch % 100 == 0:
      print('Epoch: ', e + 1, 'Batch: ', ith_batch, 'Current Loss: ', loss.item())
      
    train_running_loss += loss.item()




 ###### Validation  
  else:
    with torch.no_grad(): 
      model.eval()
      for ith_batch, sample_batched in enumerate(validation_loader):
          X_val = sample_batched['image'].to('cuda')
          y_val = sample_batched['gt'].to('cuda')
          y_pred = model(X_val)
          #out_val = (y_out + 0.5).int().float()        
          val_loss = FocalLoss()(y_pred, y_val.float())
          dicel=DiceLoss()(y_pred, y_val)
          validation_running_loss += val_loss.item()
          dice_loss+=dicel.item()
  if (e+1)%10==0:
    torch.save({'model_state_dict':model.state_dict(), 
                'epoch':e,
                'optimizer_state_dict':optimizer.state_dict(),
                'loss':loss.item()}, "/content/gdrive/MyDrive/Stroke/bs_2_Focal_Loss_epoch{}".format(e+1))


 #########################Print error         

  print("================================================================================")
  print("Epoch {} completed".format(e + 1))
      
  train_epoch_loss = train_running_loss / len(train_loader)
  validation_epoch_loss = validation_running_loss / len(validation_loader)
  valid_dice_score=1-dice_loss/len(validation_loader)    
  print("Average train loss is {}: ".format(train_epoch_loss))
  print("Average validation loss is {}".format(validation_epoch_loss))
  print("Average validation dice coef is {}".format(valid_dice_score))

  print("================================================================================")
  train_running_loss_history.append(train_epoch_loss)
  validation_running_loss_history.append(validation_epoch_loss)
  dice_coeff_focalfn.append(valid_dice_score)

torch.cuda.empty_cache()

plt.plot(train_running_loss_history, label = 'Train Loss')
plt.plot(validation_running_loss_history, label = 'Validation Loss')
plt.legend()
plt.title("Train and valid Loss")
plt.ylabel("Loss")
plt.xlabel("Epochs")
max_dice_coef=max(dice_coeff_focalfn)
index=np.argmax(dice_coeff_focalfn)+1
print("Highest validation dice score: {} at epoch {} ".format(max_dice_coef,index))
# Out:
# Epoch:  1 Batch:  0 Current Loss:  0.6849998235702515
# Epoch:  1 Batch:  100 Current Loss:  0.06320688873529434
# ================================================================================
# Epoch 1 completed
# Average train loss is 0.13723267530639693:
# Average validation loss is 0.5789616446237307
# Average validation dice coef is 0.08417424479046387
# ================================================================================
# Epoch:  2 Batch:  0 Current Loss:  0.07268813997507095
# Epoch:  2 Batch:  100 Current Loss:  0.03707260638475418
# ================================================================================
# Epoch 2 completed
# Average train loss is 0.052605240886444096:
# Average validation loss is 0.03208120096776936
# Average validation dice coef is 0.08900907877329234
# ================================================================================
# Epoch:  3 Batch:  0 Current Loss:  0.04323643818497658
# Epoch:  3 Batch:  100 Current Loss:  0.026813585311174393
# ================================================================================
# Epoch 3 completed
# Average train loss is 0.028896131718607797:
# Average validation loss is 0.025144836311606137
# Average validation dice coef is 0.12942398883200978
# ================================================================================
# Epoch:  4 Batch:  0 Current Loss:  0.017891038209199905
# Epoch:  4 Batch:  100 Current Loss:  0.02375057339668274
# ================================================================================
# Epoch 4 completed
# Average train loss is 0.020477249835656113:
# Average validation loss is 0.019829753610129293
# Average validation dice coef is 0.16797810470735708
# ================================================================================
# Epoch:  5 Batch:  0 Current Loss:  0.021672580391168594
# Epoch:  5 Batch:  100 Current Loss:  0.018016213551163673
# ================================================================================
# Epoch 5 completed
# Average train loss is 0.01626679196009693:
# Average validation loss is 0.018381779723976914
# Average validation dice coef is 0.19344451298584808
# ================================================================================
# Epoch:  6 Batch:  0 Current Loss:  0.031577739864587784
# Epoch:  6 Batch:  100 Current Loss:  0.023006059229373932
# ================================================================================
# Epoch 6 completed
# Average train loss is 0.014306216672930408:
# Average validation loss is 0.015415626213055205
# Average validation dice coef is 0.17398793955106995
# ================================================================================
# Epoch:  7 Batch:  0 Current Loss:  0.007246679626405239
# Epoch:  7 Batch:  100 Current Loss:  0.0066732382401824
# ================================================================================
# Epoch 7 completed
# Average train loss is 0.012573773322040087:
# Average validation loss is 0.012526159413863678
# Average validation dice coef is 0.21924516317006704
# ================================================================================
# Epoch:  8 Batch:  0 Current Loss:  0.028288936242461205
# Epoch:  8 Batch:  100 Current Loss:  0.015205343253910542
# ================================================================================
# Epoch 8 completed
# Average train loss is 0.010887650158957974:
# Average validation loss is 0.01335671659861062
# Average validation dice coef is 0.15609230705209676
# ================================================================================
# Epoch:  9 Batch:  0 Current Loss:  0.019916484132409096
# Epoch:  9 Batch:  100 Current Loss:  0.010825859382748604
# ================================================================================
# Epoch 9 completed
# Average train loss is 0.009977963520213962:
# Average validation loss is 0.01137230301754096
# Average validation dice coef is 0.1946638661461908
# ================================================================================
# Epoch:  10 Batch:  0 Current Loss:  0.005261825397610664
# Epoch:  10 Batch:  100 Current Loss:  0.0077266874723136425
# ================================================================================
# Epoch 10 completed
# Average train loss is 0.009274420022250039:
# Average validation loss is 0.011330372361290092
# Average validation dice coef is 0.20841243460371683
# ================================================================================
# Epoch:  11 Batch:  0 Current Loss:  0.003909954335540533
# Epoch:  11 Batch:  100 Current Loss:  0.00802602618932724
# ================================================================================
# Epoch 11 completed
# Average train loss is 0.00850185067935094:
# Average validation loss is 0.011613690442204274
# Average validation dice coef is 0.252371296689317
# ================================================================================
# Epoch:  12 Batch:  0 Current Loss:  0.005129928234964609
# Epoch:  12 Batch:  100 Current Loss:  0.007198004983365536
# ================================================================================
# Epoch 12 completed
# Average train loss is 0.00844128755693107:
# Average validation loss is 0.010223607104775068
# Average validation dice coef is 0.25231265216260346
# ================================================================================
# Epoch:  13 Batch:  0 Current Loss:  0.010298322886228561
# Epoch:  13 Batch:  100 Current Loss:  0.0042556882835924625
# ================================================================================
# Epoch 13 completed
# Average train loss is 0.008189004708770407:
# Average validation loss is 0.010970366382467988
# Average validation dice coef is 0.24103831600498504
# ================================================================================
# Epoch:  14 Batch:  0 Current Loss:  0.012522797100245953
# Epoch:  14 Batch:  100 Current Loss:  0.004969753324985504
# ================================================================================
# Epoch 14 completed
# Average train loss is 0.007505212427270025:
# Average validation loss is 0.010593619043435398
# Average validation dice coef is 0.24822786047651957
# ================================================================================
# Epoch:  15 Batch:  0 Current Loss:  0.010155475698411465
# Epoch:  15 Batch:  100 Current Loss:  0.008853896521031857
# ================================================================================
# Epoch 15 completed
# Average train loss is 0.007272020813192509:
# Average validation loss is 0.009296335589858023
# Average validation dice coef is 0.2524954418878298
# ================================================================================
# Epoch:  16 Batch:  0 Current Loss:  0.00816954392939806
# Epoch:  16 Batch:  100 Current Loss:  0.004149389453232288
# ================================================================================
# Epoch 16 completed
# Average train loss is 0.006727311765768706:
# Average validation loss is 0.010906956366238158
# Average validation dice coef is 0.24663599761756694
# ================================================================================
# Epoch:  17 Batch:  0 Current Loss:  0.003701332025229931
# Epoch:  17 Batch:  100 Current Loss:  0.0031138926278799772
# ================================================================================
# Epoch 17 completed
# Average train loss is 0.007091402798597637:
# Average validation loss is 0.010415745817275869
# Average validation dice coef is 0.2568178595723333
# ================================================================================
# Epoch:  18 Batch:  0 Current Loss:  0.005868933629244566
# Epoch:  18 Batch:  100 Current Loss:  0.008710026741027832
# ================================================================================
# Epoch 18 completed
# Average train loss is 0.006616706030972762:
# Average validation loss is 0.026948247872595046
# Average validation dice coef is 0.30631667536658214
# ================================================================================
# Epoch:  19 Batch:  0 Current Loss:  0.00436152471229434
# Epoch:  19 Batch:  100 Current Loss:  0.017749905586242676
# ================================================================================
# Epoch 19 completed
# Average train loss is 0.006737486073390058:
# Average validation loss is 0.009017061659235609
# Average validation dice coef is 0.2903433989834141
# ================================================================================
# Epoch:  20 Batch:  0 Current Loss:  0.0065325102768838406
# Epoch:  20 Batch:  100 Current Loss:  0.008318276144564152
# ================================================================================
# Epoch 20 completed
# Average train loss is 0.00605170625702108:
# Average validation loss is 0.008095543712025156
# Average validation dice coef is 0.3227914813402537
# ================================================================================
# Epoch:  21 Batch:  0 Current Loss:  0.0047319806180894375
# Epoch:  21 Batch:  100 Current Loss:  0.010337503626942635
# ================================================================================
# Epoch 21 completed
# Average train loss is 0.006104595235976301:
# Average validation loss is 0.00875195171180609
# Average validation dice coef is 0.2766696488535082
# ================================================================================
# Epoch:  22 Batch:  0 Current Loss:  0.001862666686065495
# Epoch:  22 Batch:  100 Current Loss:  0.007198941428214312
# ================================================================================
# Epoch 22 completed
# Average train loss is 0.0062266586321304005:
# Average validation loss is 0.008568065662591441
# Average validation dice coef is 0.29044637164554077
# ================================================================================
# Epoch:  23 Batch:  0 Current Loss:  0.0010637869127094746
# Epoch:  23 Batch:  100 Current Loss:  0.008084938861429691
# ================================================================================
# Epoch 23 completed
# Average train loss is 0.006597130568953205:
# Average validation loss is 0.008001381421235163
# Average validation dice coef is 0.3443909190796517
# ================================================================================
# Epoch:  24 Batch:  0 Current Loss:  0.0057530696503818035
# Epoch:  24 Batch:  100 Current Loss:  0.011072204448282719
# ================================================================================
# Epoch 24 completed
# Average train loss is 0.006037220853215007:
# Average validation loss is 0.013204560265876353
# Average validation dice coef is 0.22201462210835632
# ================================================================================
# Epoch:  25 Batch:  0 Current Loss:  0.00847084540873766
# Epoch:  25 Batch:  100 Current Loss:  0.0016863535856828094
# ================================================================================
# Epoch 25 completed
# Average train loss is 0.005573967501221301:
# Average validation loss is 0.017534172127803636
# Average validation dice coef is 0.3080704663250897
# ================================================================================
# Epoch:  26 Batch:  0 Current Loss:  0.0035591733176261187
# Epoch:  26 Batch:  100 Current Loss:  0.004539822693914175
# ================================================================================
# Epoch 26 completed
# Average train loss is 0.005354095604796958:
# Average validation loss is 0.008535730161678952
# Average validation dice coef is 0.33415180766904673
# ================================================================================
# Epoch:  27 Batch:  0 Current Loss:  0.004496694542467594
# Epoch:  27 Batch:  100 Current Loss:  0.004005772992968559
# ================================================================================
# Epoch 27 completed
# Average train loss is 0.005926715379121573:
# Average validation loss is 0.009488953651885528
# Average validation dice coef is 0.2893452692676235
# ================================================================================
# Epoch:  28 Batch:  0 Current Loss:  0.006397109013050795
# Epoch:  28 Batch:  100 Current Loss:  0.003606259822845459
# ================================================================================
# Epoch 28 completed
# Average train loss is 0.005475267806179719:
# Average validation loss is 0.0073813443761193065
# Average validation dice coef is 0.3069205992930645
# ================================================================================
# Epoch:  29 Batch:  0 Current Loss:  0.007186654955148697
# Epoch:  29 Batch:  100 Current Loss:  0.004499897826462984
# ================================================================================
# Epoch 29 completed
# Average train loss is 0.005141251909064945:
# Average validation loss is 0.0221458224003908
# Average validation dice coef is 0.2624677290787568
# ================================================================================
# Epoch:  30 Batch:  0 Current Loss:  0.004224569071084261
# Epoch:  30 Batch:  100 Current Loss:  0.0035746765788644552
# ================================================================================
# Epoch 30 completed
# Average train loss is 0.005100995710451309:
# Average validation loss is 0.0155405739394671
# Average validation dice coef is 0.339037658394994
# ================================================================================
# Epoch:  31 Batch:  0 Current Loss:  0.0018845540471374989
# Epoch:  31 Batch:  100 Current Loss:  0.0024025209713727236
# ================================================================================
# Epoch 31 completed
# Average train loss is 0.005416601057657143:
# Average validation loss is 0.01757090662864062
# Average validation dice coef is 0.2853924454869451
# ================================================================================
# Epoch:  32 Batch:  0 Current Loss:  0.00156529457308352
# Epoch:  32 Batch:  100 Current Loss:  0.01136462390422821
# ================================================================================
# Epoch 32 completed
# Average train loss is 0.004748520026324725:
# Average validation loss is 0.018907369503820617
# Average validation dice coef is 0.26629407985790354
# ================================================================================
# Epoch:  33 Batch:  0 Current Loss:  0.013756688684225082
# Epoch:  33 Batch:  100 Current Loss:  0.0028238631784915924
# ================================================================================
# Epoch 33 completed
# Average train loss is 0.004423728296836226:
# Average validation loss is 0.03229589976065138
# Average validation dice coef is 0.31742994205371755
# ================================================================================
# Epoch:  34 Batch:  0 Current Loss:  0.002472006483003497
# Epoch:  34 Batch:  100 Current Loss:  0.004996330011636019
# ================================================================================
# Epoch 34 completed
# Average train loss is 0.004434302697804986:
# Average validation loss is 0.04933802521554753
# Average validation dice coef is 0.32660608517157064
# ================================================================================
# Epoch:  35 Batch:  0 Current Loss:  0.006457105744630098
# Epoch:  35 Batch:  100 Current Loss:  0.0018674677703529596
# ================================================================================
# Epoch 35 completed
# Average train loss is 0.004253230930372996:
# Average validation loss is 0.02406495011008873
# Average validation dice coef is 0.3830123060458416
# ================================================================================
# Epoch:  36 Batch:  0 Current Loss:  0.009183889254927635
# Epoch:  36 Batch:  100 Current Loss:  0.00679100351408124
# ================================================================================
# Epoch 36 completed
# Average train loss is 0.0045002897815022945:
# Average validation loss is 0.013691606494044332
# Average validation dice coef is 0.3286036639600187
# ================================================================================
# Epoch:  37 Batch:  0 Current Loss:  0.005525518674403429
# Epoch:  37 Batch:  100 Current Loss:  0.007974292151629925
# ================================================================================
# Epoch 37 completed
# Average train loss is 0.004574370029069841:
# Average validation loss is 0.0242075519903714
# Average validation dice coef is 0.33983928770632355
# ================================================================================
# Epoch:  38 Batch:  0 Current Loss:  0.003249729285016656
# Epoch:  38 Batch:  100 Current Loss:  0.0047098444774746895
# ================================================================================
# Epoch 38 completed
# Average train loss is 0.004132344345211319:
# Average validation loss is 0.01358491280493704
# Average validation dice coef is 0.339354614953737
# ================================================================================
# Epoch:  39 Batch:  0 Current Loss:  0.005374514032155275
# Epoch:  39 Batch:  100 Current Loss:  0.0018149020615965128
# ================================================================================
# Epoch 39 completed
# Average train loss is 0.004058196898294638:
# Average validation loss is 0.009606214914301008
# Average validation dice coef is 0.3333087934030069
# ================================================================================
# Epoch:  40 Batch:  0 Current Loss:  0.0011964787263423204
# Epoch:  40 Batch:  100 Current Loss:  0.0031540710479021072
# ================================================================================
# Epoch 40 completed
# Average train loss is 0.003919415133056384:
# Average validation loss is 0.014816243251835977
# Average validation dice coef is 0.3245677947998047
# ================================================================================
# Epoch:  41 Batch:  0 Current Loss:  0.0019926554523408413
# Epoch:  41 Batch:  100 Current Loss:  0.0010909949196502566
# ================================================================================
# Epoch 41 completed
# Average train loss is 0.0037886555279104347:
# Average validation loss is 0.011062961424121985
# Average validation dice coef is 0.35801857709884644
# ================================================================================
# Epoch:  42 Batch:  0 Current Loss:  0.00220521935261786
# Epoch:  42 Batch:  100 Current Loss:  0.0027501750737428665
# ================================================================================
# Epoch 42 completed
# Average train loss is 0.00377241116095245:
# Average validation loss is 0.009985311718648174
# Average validation dice coef is 0.29023138413558136
# ================================================================================
# Epoch:  43 Batch:  0 Current Loss:  0.007191314361989498
# Epoch:  43 Batch:  100 Current Loss:  0.0021470021456480026
# ================================================================================
# Epoch 43 completed
# Average train loss is 0.003733132567180142:
# Average validation loss is 0.013531557494315092
# Average validation dice coef is 0.3324484841243641
# ================================================================================
# Epoch:  44 Batch:  0 Current Loss:  0.0008412146707996726
# Epoch:  44 Batch:  100 Current Loss:  0.0030318498611450195
# ================================================================================
# Epoch 44 completed
# Average train loss is 0.0037730987030655553:
# Average validation loss is 0.00750634994364117
# Average validation dice coef is 0.37215584194338003
# ================================================================================
# Epoch:  45 Batch:  0 Current Loss:  0.0027266948018223047
# Epoch:  45 Batch:  100 Current Loss:  0.0087825246155262
# ================================================================================
# Epoch 45 completed
# Average train loss is 0.004168483865214512:
# Average validation loss is 0.009979956239033994
# Average validation dice coef is 0.36569582932704203
# ================================================================================
# Epoch:  46 Batch:  0 Current Loss:  0.0005063469288870692
# Epoch:  46 Batch:  100 Current Loss:  0.003678117645904422
# ================================================================================
# Epoch 46 completed
# Average train loss is 0.003778149540279354:
# Average validation loss is 0.013230077892453788
# Average validation dice coef is 0.3450583815574646
# ================================================================================
# Epoch:  47 Batch:  0 Current Loss:  0.0034181883092969656
# Epoch:  47 Batch:  100 Current Loss:  0.0021338253282010555
# ================================================================================
# Epoch 47 completed
# Average train loss is 0.0036239812924241175:
# Average validation loss is 0.008083649247104453
# Average validation dice coef is 0.3727908215007266
# ================================================================================
# Epoch:  48 Batch:  0 Current Loss:  0.0012989705428481102
# Epoch:  48 Batch:  100 Current Loss:  0.0022217310033738613
# ================================================================================
# Epoch 48 completed
# Average train loss is 0.003396032428710198:
# Average validation loss is 0.007313321914832183
# Average validation dice coef is 0.3887968675510304
# ================================================================================
# Epoch:  49 Batch:  0 Current Loss:  0.0039269630797207355
# Epoch:  49 Batch:  100 Current Loss:  0.0012170360423624516
# ================================================================================
# Epoch 49 completed
# Average train loss is 0.0034242401221266324:
# Average validation loss is 0.009031323144980077
# Average validation dice coef is 0.375097753228368
# ================================================================================
# Epoch:  50 Batch:  0 Current Loss:  0.0012757311342284083
# Epoch:  50 Batch:  100 Current Loss:  0.0018583933124318719
# ================================================================================
# Epoch 50 completed
# Average train loss is 0.003184973756218176:
# Average validation loss is 0.011223975005811331
# Average validation dice coef is 0.43038495005788024
# ================================================================================
# Epoch:  51 Batch:  0 Current Loss:  0.006832990795373917
# Epoch:  51 Batch:  100 Current Loss:  0.012027200311422348
# ================================================================================
# Epoch 51 completed
# Average train loss is 0.0033569860223071546:
# Average validation loss is 0.008450250920046726
# Average validation dice coef is 0.35342116452552175
# ================================================================================
# Epoch:  52 Batch:  0 Current Loss:  0.00398284662514925
# Epoch:  52 Batch:  100 Current Loss:  0.0022907815873622894
# ================================================================================
# Epoch 52 completed
# Average train loss is 0.0029898046299397358:
# Average validation loss is 0.009630871992526777
# Average validation dice coef is 0.37687241708910146
# ================================================================================
# Epoch:  53 Batch:  0 Current Loss:  0.0018271550070494413
# Epoch:  53 Batch:  100 Current Loss:  0.005258929915726185
# ================================================================================
# Epoch 53 completed
# Average train loss is 0.0028497396219977853:
# Average validation loss is 0.007927538995391916
# Average validation dice coef is 0.3797724907462662
# ================================================================================
# Epoch:  54 Batch:  0 Current Loss:  0.000647703418508172
# Epoch:  54 Batch:  100 Current Loss:  0.003016612259671092
# ================================================================================
# Epoch 54 completed
# Average train loss is 0.0028507703021591313:
# Average validation loss is 0.009193864306497917
# Average validation dice coef is 0.35916324080647644
# ================================================================================
# Epoch:  55 Batch:  0 Current Loss:  0.0019918547477573156
# Epoch:  55 Batch:  100 Current Loss:  0.001862190430983901
# ================================================================================
# Epoch 55 completed
# Average train loss is 0.0030500465394627647:
# Average validation loss is 0.009427688276470714
# Average validation dice coef is 0.3063262878237544
# ================================================================================
# Epoch:  56 Batch:  0 Current Loss:  0.007059005554765463
# Epoch:  56 Batch:  100 Current Loss:  0.000889977382030338
# ================================================================================
# Epoch 56 completed
# Average train loss is 0.0029375480690473463:
# Average validation loss is 0.008749730912166194
# Average validation dice coef is 0.35288976495330393
# ================================================================================
# Epoch:  57 Batch:  0 Current Loss:  0.002973203081637621
# Epoch:  57 Batch:  100 Current Loss:  0.0021604630164802074
# ================================================================================
# Epoch 57 completed
# Average train loss is 0.002982831620077016:
# Average validation loss is 0.0067542277479456184
# Average validation dice coef is 0.3786798538388433
# ================================================================================
# Epoch:  58 Batch:  0 Current Loss:  0.00668631587177515
# Epoch:  58 Batch:  100 Current Loss:  0.0007519726059399545
# ================================================================================
# Epoch 58 completed
# Average train loss is 0.0027777096344323905:
# Average validation loss is 0.007726039479461474
# Average validation dice coef is 0.41959883554561717
# ================================================================================
# Epoch:  59 Batch:  0 Current Loss:  0.0012516650604084134
# Epoch:  59 Batch:  100 Current Loss:  0.0006242517265491188
# ================================================================================
# Epoch 59 completed
# Average train loss is 0.002448456245574188:
# Average validation loss is 0.007623735154551026
# Average validation dice coef is 0.37176123341998535
# ================================================================================
# Epoch:  60 Batch:  0 Current Loss:  0.002701794495806098
# Epoch:  60 Batch:  100 Current Loss:  0.0020822675433009863
# ================================================================================
# Epoch 60 completed
# Average train loss is 0.0024508354528659593:
# Average validation loss is 0.02481988851906027
# Average validation dice coef is 0.38218121915250214
# ================================================================================
# Epoch:  61 Batch:  0 Current Loss:  0.0008078540558926761
# Epoch:  61 Batch:  100 Current Loss:  0.0005606182385236025
# ================================================================================
# Epoch 61 completed
# Average train loss is 0.0022519248967698443:
# Average validation loss is 0.007136751241617005
# Average validation dice coef is 0.3899215830338968
# ================================================================================
# Epoch:  62 Batch:  0 Current Loss:  0.0023140821140259504
# Epoch:  62 Batch:  100 Current Loss:  0.0016383614856749773
# ================================================================================
# Epoch 62 completed
# Average train loss is 0.002766504486877637:
# Average validation loss is 0.007107975222547916
# Average validation dice coef is 0.37796418086902517
# ================================================================================
# Epoch:  63 Batch:  0 Current Loss:  0.0014072228223085403
# Epoch:  63 Batch:  100 Current Loss:  0.0031618820503354073
# ================================================================================
# Epoch 63 completed
# Average train loss is 0.002143750239318326:
# Average validation loss is 0.006901442794588621
# Average validation dice coef is 0.4485678640571801
# ================================================================================
# Epoch:  64 Batch:  0 Current Loss:  0.0011185379698872566
# Epoch:  64 Batch:  100 Current Loss:  0.004890190903097391
# ================================================================================
# Epoch 64 completed
# Average train loss is 0.0020792996514351777:
# Average validation loss is 0.009145298036683753
# Average validation dice coef is 0.46044850832707174
# ================================================================================
# Epoch:  65 Batch:  0 Current Loss:  0.0008583643357269466
# Epoch:  65 Batch:  100 Current Loss:  0.0029908905271440744
# ================================================================================
# Epoch 65 completed
# Average train loss is 0.0023570678014749155:
# Average validation loss is 0.008072454553110071
# Average validation dice coef is 0.4069972940393396
# ================================================================================
# Epoch:  66 Batch:  0 Current Loss:  0.0021552329417318106
# Epoch:  66 Batch:  100 Current Loss:  0.002659938298165798
# ================================================================================
# Epoch 66 completed
# Average train loss is 0.002520151682216387:
# Average validation loss is 0.007875792535078535
# Average validation dice coef is 0.39564288467974273
# ================================================================================
# Epoch:  67 Batch:  0 Current Loss:  0.0016552699962630868
# Epoch:  67 Batch:  100 Current Loss:  0.0048783463425934315
# ================================================================================
# Epoch 67 completed
# Average train loss is 0.0019136750151655215:
# Average validation loss is 0.007604272597205095
# Average validation dice coef is 0.41758657790519094
# ================================================================================
# Epoch:  68 Batch:  0 Current Loss:  0.0013763338793069124
# Epoch:  68 Batch:  100 Current Loss:  0.002798554953187704
# ================================================================================
# Epoch 68 completed
# Average train loss is 0.001878203360195597:
# Average validation loss is 0.007567195276843032
# Average validation dice coef is 0.44330443240500783
# ================================================================================
# Epoch:  69 Batch:  0 Current Loss:  0.0036868236493319273
# Epoch:  69 Batch:  100 Current Loss:  0.0014424673281610012
# ================================================================================
# Epoch 69 completed
# Average train loss is 0.0017889363180697666:
# Average validation loss is 0.009184750642570844
# Average validation dice coef is 0.3652789576633556
# ================================================================================
# Epoch:  70 Batch:  0 Current Loss:  0.0018912522355094552
# Epoch:  70 Batch:  100 Current Loss:  0.0003104987263213843
# ================================================================================
# Epoch 70 completed
# Average train loss is 0.0016799256957474177:
# Average validation loss is 0.008973104967358144
# Average validation dice coef is 0.3849055187122242
# ================================================================================
# Epoch:  71 Batch:  0 Current Loss:  0.001824627397581935
# Epoch:  71 Batch:  100 Current Loss:  0.003379564266651869
# ================================================================================
# Epoch 71 completed
# Average train loss is 0.0018480341901049044:
# Average validation loss is 0.012826149207162293
# Average validation dice coef is 0.3848012170276126
# ================================================================================
# Epoch:  72 Batch:  0 Current Loss:  0.0008746676030568779
# Epoch:  72 Batch:  100 Current Loss:  0.00044323346810415387
# ================================================================================
# Epoch 72 completed
# Average train loss is 0.001894238099787936:
# Average validation loss is 0.00952541474897943
# Average validation dice coef is 0.42597885389585755
# ================================================================================
# Epoch:  73 Batch:  0 Current Loss:  0.0023332417476922274
# Epoch:  73 Batch:  100 Current Loss:  0.001965350704267621
# ================================================================================
# Epoch 73 completed
# Average train loss is 0.0016309692604508737:
# Average validation loss is 0.008197196899296565
# Average validation dice coef is 0.4503331909308562
# ================================================================================
# Epoch:  74 Batch:  0 Current Loss:  0.0002771029539871961
# Epoch:  74 Batch:  100 Current Loss:  0.001989441690966487
# ================================================================================
# Epoch 74 completed
# Average train loss is 0.0018195577361202345:
# Average validation loss is 0.008285991164754975
# Average validation dice coef is 0.45294525655540263
# ================================================================================
# Epoch:  75 Batch:  0 Current Loss:  0.0016748979687690735
# Epoch:  75 Batch:  100 Current Loss:  0.00157675810623914
# ================================================================================
# Epoch 75 completed
# Average train loss is 0.001435745761937889:
# Average validation loss is 0.010747729627591735
# Average validation dice coef is 0.4151625617130382
# ================================================================================
# Epoch:  76 Batch:  0 Current Loss:  0.0001655042142374441
# Epoch:  76 Batch:  100 Current Loss:  0.0011767279356718063
# ================================================================================
# Epoch 76 completed
# Average train loss is 0.0016914899117107605:
# Average validation loss is 0.00788935024064739
# Average validation dice coef is 0.45926177501678467
# ================================================================================
# Epoch:  77 Batch:  0 Current Loss:  0.0002689497487153858
# Epoch:  77 Batch:  100 Current Loss:  0.002248708624392748
# ================================================================================
# Epoch 77 completed
# Average train loss is 0.0014811445775917056:
# Average validation loss is 0.010469251148704742
# Average validation dice coef is 0.35209662688745036
# ================================================================================
# Epoch:  78 Batch:  0 Current Loss:  0.0018544674385339022
# Epoch:  78 Batch:  100 Current Loss:  0.0014871768653392792
# ================================================================================
# Epoch 78 completed
# Average train loss is 0.0012374172658557456:
# Average validation loss is 0.00769085033509229
# Average validation dice coef is 0.40516271623405253
# ================================================================================
# Epoch:  79 Batch:  0 Current Loss:  0.0002022173284785822
# Epoch:  79 Batch:  100 Current Loss:  0.002132399706169963
# ================================================================================
# Epoch 79 completed
# Average train loss is 0.0011871648025029173:
# Average validation loss is 0.011627846693217352
# Average validation dice coef is 0.4519454273017677
# ================================================================================
# Epoch:  80 Batch:  0 Current Loss:  0.0007895982125774026
# Epoch:  80 Batch:  100 Current Loss:  0.0010311525547876954
# ================================================================================
# Epoch 80 completed
# Average train loss is 0.0012959627837679439:
# Average validation loss is 0.007840300711954164
# Average validation dice coef is 0.48034937317306936
# ================================================================================
# Epoch:  81 Batch:  0 Current Loss:  0.0009546689107082784
# Epoch:  81 Batch:  100 Current Loss:  0.0014677675208076835
# ================================================================================
# Epoch 81 completed
# Average train loss is 0.0016969369729575765:
# Average validation loss is 0.008056073821412487
# Average validation dice coef is 0.462367785943521
# ================================================================================
# Epoch:  82 Batch:  0 Current Loss:  0.0015583594795316458
# Epoch:  82 Batch:  100 Current Loss:  0.0011240311432629824
# ================================================================================
# Epoch 82 completed
# Average train loss is 0.0012308725730291958:
# Average validation loss is 0.009270701013077554
# Average validation dice coef is 0.45831920327367004
# ================================================================================
# Epoch:  83 Batch:  0 Current Loss:  0.00024908417253755033
# Epoch:  83 Batch:  100 Current Loss:  0.00029996386729180813
# ================================================================================
# Epoch 83 completed
# Average train loss is 0.0012789000853719126:
# Average validation loss is 0.007408433810908448
# Average validation dice coef is 0.4881811818561038
# ================================================================================
# Epoch:  84 Batch:  0 Current Loss:  0.001125588663853705
# Epoch:  84 Batch:  100 Current Loss:  0.0065447259694337845
# ================================================================================
# Epoch 84 completed
# Average train loss is 0.0017718704003116678:
# Average validation loss is 0.00894605036041498
# Average validation dice coef is 0.43002304032042216
# ================================================================================
# Epoch:  85 Batch:  0 Current Loss:  0.0007450389093719423
# Epoch:  85 Batch:  100 Current Loss:  0.002224233467131853
# ================================================================================
# Epoch 85 completed
# Average train loss is 0.0015328039545699401:
# Average validation loss is 0.00988542616707147
# Average validation dice coef is 0.4244759711059364
# ================================================================================
# Epoch:  86 Batch:  0 Current Loss:  0.0033734068274497986
# Epoch:  86 Batch:  100 Current Loss:  0.0022503335494548082
# ================================================================================
# Epoch 86 completed
# Average train loss is 0.0014509030546808028:
# Average validation loss is 0.009511238384859738
# Average validation dice coef is 0.4573713041640617
# ================================================================================
# Epoch:  87 Batch:  0 Current Loss:  0.0016644079005345702
# Epoch:  87 Batch:  100 Current Loss:  0.00024531976669095457
# ================================================================================
# Epoch 87 completed
# Average train loss is 0.0010602959052560697:
# Average validation loss is 0.008528707100619638
# Average validation dice coef is 0.4552554697603792
# ================================================================================
# Epoch:  88 Batch:  0 Current Loss:  0.0006716757197864354
# Epoch:  88 Batch:  100 Current Loss:  3.325357101857662e-05
# ================================================================================
# Epoch 88 completed
# Average train loss is 0.0009192924997179246:
# Average validation loss is 0.008356302216762325
# Average validation dice coef is 0.4526867399344573
# ================================================================================
# Epoch:  89 Batch:  0 Current Loss:  0.0007050744607113302
# Epoch:  89 Batch:  100 Current Loss:  0.0017563441069796681
# ================================================================================
# Epoch 89 completed
# Average train loss is 0.0008882795406101999:
# Average validation loss is 0.009046484112528758
# Average validation dice coef is 0.44711509588602427
# ================================================================================
# Epoch:  90 Batch:  0 Current Loss:  0.0003758044622372836
# Epoch:  90 Batch:  100 Current Loss:  0.0014601118164137006
# ================================================================================
# Epoch 90 completed
# Average train loss is 0.0008797100191969387:
# Average validation loss is 0.009610926297436645
# Average validation dice coef is 0.4224308487531301
# ================================================================================
# Epoch:  91 Batch:  0 Current Loss:  0.002029537921771407
# Epoch:  91 Batch:  100 Current Loss:  0.0006220281356945634
# ================================================================================
# Epoch 91 completed
# Average train loss is 0.0009080698633525036:
# Average validation loss is 0.009874232251801202
# Average validation dice coef is 0.431139084132942
# ================================================================================
# Epoch:  92 Batch:  0 Current Loss:  0.0023285772185772657
# Epoch:  92 Batch:  100 Current Loss:  0.0008829782018437982
# ================================================================================
# Epoch 92 completed
# Average train loss is 0.0009504940856347013:
# Average validation loss is 0.010906557448293283
# Average validation dice coef is 0.45322196064768616
# ================================================================================
# Epoch:  93 Batch:  0 Current Loss:  0.00010445015504956245
# Epoch:  93 Batch:  100 Current Loss:  0.0015381018165498972
# ================================================================================
# Epoch 93 completed
# Average train loss is 0.0009111434353879503:
# Average validation loss is 0.009085319587816106
# Average validation dice coef is 0.4862566703074688
# ================================================================================
# Epoch:  94 Batch:  0 Current Loss:  0.0010264333104714751
# Epoch:  94 Batch:  100 Current Loss:  0.0009259856306016445
# ================================================================================
# Epoch 94 completed
# Average train loss is 0.0009116631855959733:
# Average validation loss is 0.010495270064377503
# Average validation dice coef is 0.4364808024586858
# ================================================================================
# Epoch:  95 Batch:  0 Current Loss:  0.0008506253361701965
# Epoch:  95 Batch:  100 Current Loss:  0.0017639363650232553
# ================================================================================
# Epoch 95 completed
# Average train loss is 0.0008855049989207358:
# Average validation loss is 0.009882556364204534
# Average validation dice coef is 0.4884659261316866
# ================================================================================
# Epoch:  96 Batch:  0 Current Loss:  0.0010625277645885944
# Epoch:  96 Batch:  100 Current Loss:  0.00012692069867625833
# ================================================================================
# Epoch 96 completed
# Average train loss is 0.0008996029435565267:
# Average validation loss is 0.01002668875672326
# Average validation dice coef is 0.4660738642151291
# ================================================================================
# Epoch:  97 Batch:  0 Current Loss:  0.0014950449112802744
# Epoch:  97 Batch:  100 Current Loss:  0.00028296629898250103
# ================================================================================
# Epoch 97 completed
# Average train loss is 0.0009505634482855086:
# Average validation loss is 0.01243454877938446
# Average validation dice coef is 0.4141670239938272
# ================================================================================
# Epoch:  98 Batch:  0 Current Loss:  0.00034260068787261844
# Epoch:  98 Batch:  100 Current Loss:  0.0012972053373232484
# ================================================================================
# Epoch 98 completed
# Average train loss is 0.0011846505360951335:
# Average validation loss is 0.008374109249121535
# Average validation dice coef is 0.45981652833319997
# ================================================================================
# Epoch:  99 Batch:  0 Current Loss:  7.434388680849224e-05
# Epoch:  99 Batch:  100 Current Loss:  0.0014275418361648917
# ================================================================================
# Epoch 99 completed
# Average train loss is 0.0008731203931708715:
# Average validation loss is 0.00880716900684166
# Average validation dice coef is 0.498423648847116
# ================================================================================
# Epoch:  100 Batch:  0 Current Loss:  0.0001919594214996323
# Epoch:  100 Batch:  100 Current Loss:  0.0005640551098622382
# ================================================================================
# Epoch 100 completed
# Average train loss is 0.000687698986364747:
# Average validation loss is 0.011552768923433472
# Average validation dice coef is 0.4807600894489804
# ================================================================================
# Highest validation dice score: 0.498423648847116 at epoch 99

# %%
#############################Dice Loss Function

epochs = 100


train_running_loss_history = []
validation_running_loss_history =[]
dice_coeff_dicefn=[]

for e in range(epochs):
  dice_loss=0.0
  train_running_loss = 0.0
  validation_running_loss = 0.0
  
  model.train()
  
  for ith_batch, sample_batched in enumerate(train_loader):
    X_train = sample_batched['image'].to('cuda')
    y_train = sample_batched['gt'].to('cuda')

    optimizer.zero_grad()
    y_pred = model(X_train)
   #out = (y_pred + 0.5).int().float()
    
    #loss = FocalLoss()(y_pred,y_train)/N-torch.log(DiceLoss()(y_pred,y_train))
    #loss = criterion(y_pred, y_train)
    loss = DiceLoss()(y_pred,y_train)
    loss.backward()
    optimizer.step()
    
    if ith_batch % 100 == 0:
      print('Epoch: ', e + 1, 'Batch: ', ith_batch, 'Current Loss: ', loss.item())
      
    train_running_loss += loss.item()




 ###### Validation  
  else:
    with torch.no_grad(): 
      model.eval()
      for ith_batch, sample_batched in enumerate(validation_loader):
          X_val = sample_batched['image'].to('cuda')
          y_val = sample_batched['gt'].to('cuda')
          y_pred = model(X_val)
          #out_val = (y_out + 0.5).int().float()        
          val_loss = DiceLoss()(y_pred, y_val)
          dicel=DiceLoss()(y_pred, y_val)
          validation_running_loss += val_loss.item()
          dice_loss+=dicel.item()
  if (e+1)%10==0:
    torch.save({'model_state_dict':model.state_dict(), 
                'epoch':e,
                'optimizer_state_dict':optimizer.state_dict(),
                'loss':loss.item()}, "/content/gdrive/MyDrive/Stroke/bs_2_Dice_epoch{}".format(e+1))


 #########################Print error         

  print("================================================================================")
  print("Epoch {} completed".format(e + 1))
      
  train_epoch_loss = train_running_loss / len(train_loader)
  validation_epoch_loss = validation_running_loss / len(validation_loader)
  valid_dice_score=1-dice_loss/len(validation_loader)    
  print("Average train loss is {}: ".format(train_epoch_loss))
  print("Average validation loss is {}".format(validation_epoch_loss))
  print("Average validation dice coef is {}".format(valid_dice_score))

  print("================================================================================")
  train_running_loss_history.append(train_epoch_loss)
  validation_running_loss_history.append(validation_epoch_loss)
  dice_coeff_dicefn.append(valid_dice_score)

torch.cuda.empty_cache()



plt.plot(train_running_loss_history, label = 'Train Loss')
plt.plot(validation_running_loss_history, label = 'Validation Loss')
plt.legend()
plt.title("Train and valid Loss")
plt.ylabel("Loss")
plt.xlabel("Epochs")
max_dice_coef=max(dice_coeff_dicefn)
index=np.argmax(dice_coeff_dicefn)+1
print("Highest validation dice score: {} at epoch {} ".format(max_dice_coef,index))
# Out:
# Epoch:  1 Batch:  0 Current Loss:  0.9370984435081482
# Epoch:  1 Batch:  100 Current Loss:  0.8840038776397705
# ================================================================================
# Epoch 1 completed
# Average train loss is 0.8633294003467037:
# Average validation loss is 0.816912199999835
# Average validation dice coef is 0.183087800000165
# ================================================================================
# Epoch:  2 Batch:  0 Current Loss:  0.9541111588478088
# Epoch:  2 Batch:  100 Current Loss:  0.483684778213501
# ================================================================================
# Epoch 2 completed
# Average train loss is 0.7811226579424453:
# Average validation loss is 0.7457316791689074
# Average validation dice coef is 0.25426832083109263
# ================================================================================
# Epoch:  3 Batch:  0 Current Loss:  0.9266222715377808
# Epoch:  3 Batch:  100 Current Loss:  0.48599982261657715
# ================================================================================
# Epoch 3 completed
# Average train loss is 0.6816086883414282:
# Average validation loss is 0.7076387550379779
# Average validation dice coef is 0.2923612449620221
# ================================================================================
# Epoch:  4 Batch:  0 Current Loss:  0.6161701679229736
# Epoch:  4 Batch:  100 Current Loss:  0.3634970784187317
# ================================================================================
# Epoch 4 completed
# Average train loss is 0.6117122067164068:
# Average validation loss is 0.6359194839322889
# Average validation dice coef is 0.3640805160677111
# ================================================================================
# Epoch:  5 Batch:  0 Current Loss:  0.48862749338150024
# Epoch:  5 Batch:  100 Current Loss:  0.22883009910583496
# ================================================================================
# Epoch 5 completed
# Average train loss is 0.5570087147085634:
# Average validation loss is 0.6526710165513528
# Average validation dice coef is 0.34732898344864716
# ================================================================================
# Epoch:  6 Batch:  0 Current Loss:  0.4411163926124573
# Epoch:  6 Batch:  100 Current Loss:  0.45005375146865845
# ================================================================================
# Epoch 6 completed
# Average train loss is 0.5424948318363869:
# Average validation loss is 0.6621861280621709
# Average validation dice coef is 0.3378138719378291
# ================================================================================
# Epoch:  7 Batch:  0 Current Loss:  0.6747013330459595
# Epoch:  7 Batch:  100 Current Loss:  0.7392765283584595
# ================================================================================
# Epoch 7 completed
# Average train loss is 0.5504471990343642:
# Average validation loss is 0.557096321840544
# Average validation dice coef is 0.44290367815945597
# ================================================================================
# Epoch:  8 Batch:  0 Current Loss:  0.3506699800491333
# Epoch:  8 Batch:  100 Current Loss:  0.9196627140045166
# ================================================================================
# Epoch 8 completed
# Average train loss is 0.5041557819875953:
# Average validation loss is 0.6861050950514304
# Average validation dice coef is 0.31389490494856964
# ================================================================================
# Epoch:  9 Batch:  0 Current Loss:  0.6948463320732117
# Epoch:  9 Batch:  100 Current Loss:  0.1722847819328308
# ================================================================================
# Epoch 9 completed
# Average train loss is 0.5242056883361241:
# Average validation loss is 0.6126960515975952
# Average validation dice coef is 0.3873039484024048
# ================================================================================
# Epoch:  10 Batch:  0 Current Loss:  0.7278704643249512
# Epoch:  10 Batch:  100 Current Loss:  0.3351658582687378
# ================================================================================
# Epoch 10 completed
# Average train loss is 0.5125576384263496:
# Average validation loss is 0.6111567584243981
# Average validation dice coef is 0.3888432415756019
# ================================================================================
# Epoch:  11 Batch:  0 Current Loss:  0.834239661693573
# Epoch:  11 Batch:  100 Current Loss:  0.7613154053688049
# ================================================================================
# Epoch 11 completed
# Average train loss is 0.510160410240905:
# Average validation loss is 0.57512685898188
# Average validation dice coef is 0.42487314101812
# ================================================================================
# Epoch:  12 Batch:  0 Current Loss:  0.6225534677505493
# Epoch:  12 Batch:  100 Current Loss:  0.5874476432800293
# ================================================================================
# Epoch 12 completed
# Average train loss is 0.4819281464570189:
# Average validation loss is 0.6058812350840181
# Average validation dice coef is 0.39411876491598186
# ================================================================================
# Epoch:  13 Batch:  0 Current Loss:  0.32212215662002563
# Epoch:  13 Batch:  100 Current Loss:  0.20417171716690063
# ================================================================================
# Epoch 13 completed
# Average train loss is 0.5113597022343989:
# Average validation loss is 0.5234703759889345
# Average validation dice coef is 0.47652962401106547
# ================================================================================
# Epoch:  14 Batch:  0 Current Loss:  0.25563764572143555
# Epoch:  14 Batch:  100 Current Loss:  0.8904571533203125
# ================================================================================
# Epoch 14 completed
# Average train loss is 0.5004417847280633:
# Average validation loss is 0.5967053819347072
# Average validation dice coef is 0.40329461806529276
# ================================================================================
# Epoch:  15 Batch:  0 Current Loss:  0.5509039759635925
# Epoch:  15 Batch:  100 Current Loss:  0.3570610284805298
# ================================================================================
# Epoch 15 completed
# Average train loss is 0.507013736930612:
# Average validation loss is 0.5398418693929106
# Average validation dice coef is 0.46015813060708943
# ================================================================================
# Epoch:  16 Batch:  0 Current Loss:  0.5301824808120728
# Epoch:  16 Batch:  100 Current Loss:  0.9992800951004028
# ================================================================================
# Epoch 16 completed
# Average train loss is 0.5168228333127008:
# Average validation loss is 0.6263798829671499
# Average validation dice coef is 0.37362011703285014
# ================================================================================
# Epoch:  17 Batch:  0 Current Loss:  0.1817265748977661
# Epoch:  17 Batch:  100 Current Loss:  0.9983805418014526
# ================================================================================
# Epoch 17 completed
# Average train loss is 0.47364391692697183:
# Average validation loss is 0.5578866327131117
# Average validation dice coef is 0.4421133672868883
# ================================================================================
# Epoch:  18 Batch:  0 Current Loss:  0.2705767750740051
# Epoch:  18 Batch:  100 Current Loss:  0.6544084548950195
# ================================================================================
# Epoch 18 completed
# Average train loss is 0.48276948520582014:
# Average validation loss is 0.5391221851915926
# Average validation dice coef is 0.4608778148084074
# ================================================================================
# Epoch:  19 Batch:  0 Current Loss:  0.8275250196456909
# Epoch:  19 Batch:  100 Current Loss:  0.9123610854148865
# ================================================================================
# Epoch 19 completed
# Average train loss is 0.5113215205604082:
# Average validation loss is 0.5687957921543637
# Average validation dice coef is 0.4312042078456363
# ================================================================================
# Epoch:  20 Batch:  0 Current Loss:  0.998927652835846
# Epoch:  20 Batch:  100 Current Loss:  0.19782930612564087
# ================================================================================
# Epoch 20 completed
# Average train loss is 0.47834575706965304:
# Average validation loss is 0.5984256670281694
# Average validation dice coef is 0.40157433297183065
# ================================================================================
# Epoch:  21 Batch:  0 Current Loss:  0.43231910467147827
# Epoch:  21 Batch:  100 Current Loss:  0.27577531337738037
# ================================================================================
# Epoch 21 completed
# Average train loss is 0.47765949409301967:
# Average validation loss is 0.5325348812180597
# Average validation dice coef is 0.4674651187819403
# ================================================================================
# Epoch:  22 Batch:  0 Current Loss:  0.26368552446365356
# Epoch:  22 Batch:  100 Current Loss:  0.6410719156265259
# ================================================================================
# Epoch 22 completed
# Average train loss is 0.4665647422614163:
# Average validation loss is 0.5908943060282115
# Average validation dice coef is 0.40910569397178853
# ================================================================================
# Epoch:  23 Batch:  0 Current Loss:  0.36917197704315186
# Epoch:  23 Batch:  100 Current Loss:  0.4795196056365967
# ================================================================================
# Epoch 23 completed
# Average train loss is 0.48052977168396727:
# Average validation loss is 0.5810906258789269
# Average validation dice coef is 0.4189093741210731
# ================================================================================
# Epoch:  24 Batch:  0 Current Loss:  0.3056797385215759
# Epoch:  24 Batch:  100 Current Loss:  0.2611273527145386
# ================================================================================
# Epoch 24 completed
# Average train loss is 0.45429123713545605:
# Average validation loss is 0.5786400614558039
# Average validation dice coef is 0.42135993854419607
# ================================================================================
# Epoch:  25 Batch:  0 Current Loss:  0.29995661973953247
# Epoch:  25 Batch:  100 Current Loss:  0.7340949773788452
# ================================================================================
# Epoch 25 completed
# Average train loss is 0.47057719916513524:
# Average validation loss is 0.5607822698515814
# Average validation dice coef is 0.4392177301484186
# ================================================================================
# Epoch:  26 Batch:  0 Current Loss:  0.746788501739502
# Epoch:  26 Batch:  100 Current Loss:  0.560725748538971
# ================================================================================
# Epoch 26 completed
# Average train loss is 0.4792730677617739:
# Average validation loss is 0.5316532576406324
# Average validation dice coef is 0.4683467423593676
# ================================================================================
# Epoch:  27 Batch:  0 Current Loss:  0.37384581565856934
# Epoch:  27 Batch:  100 Current Loss:  0.513054609298706
# ================================================================================
# Epoch 27 completed
# Average train loss is 0.44964939519150615:
# Average validation loss is 0.5695890800372975
# Average validation dice coef is 0.43041091996270253
# ================================================================================
# Epoch:  28 Batch:  0 Current Loss:  0.7871165871620178
# Epoch:  28 Batch:  100 Current Loss:  0.24128073453903198
# ================================================================================
# Epoch 28 completed
# Average train loss is 0.4600805350362438:
# Average validation loss is 0.5350389657793818
# Average validation dice coef is 0.4649610342206182
# ================================================================================
# Epoch:  29 Batch:  0 Current Loss:  0.5722194910049438
# Epoch:  29 Batch:  100 Current Loss:  0.17960011959075928
# ================================================================================
# Epoch 29 completed
# Average train loss is 0.46673934141250506:
# Average validation loss is 0.5632996623580521
# Average validation dice coef is 0.43670033764194793
# ================================================================================
# Epoch:  30 Batch:  0 Current Loss:  0.4474782943725586
# Epoch:  30 Batch:  100 Current Loss:  0.5691351890563965
# ================================================================================
# Epoch 30 completed
# Average train loss is 0.45264398847540765:
# Average validation loss is 0.5871589828181911
# Average validation dice coef is 0.4128410171818089
# ================================================================================
# Epoch:  31 Batch:  0 Current Loss:  0.7814744710922241
# Epoch:  31 Batch:  100 Current Loss:  0.6440944075584412
# ================================================================================
# Epoch 31 completed
# Average train loss is 0.45632368856913424:
# Average validation loss is 0.5677105832744289
# Average validation dice coef is 0.4322894167255711
# ================================================================================
# Epoch:  32 Batch:  0 Current Loss:  0.3320755362510681
# Epoch:  32 Batch:  100 Current Loss:  0.2673414349555969
# ================================================================================
# Epoch 32 completed
# Average train loss is 0.45041045056630485:
# Average validation loss is 0.5164605282448433
# Average validation dice coef is 0.48353947175515666
# ================================================================================
# Epoch:  33 Batch:  0 Current Loss:  0.48691892623901367
# Epoch:  33 Batch:  100 Current Loss:  0.9193881750106812
# ================================================================================
# Epoch 33 completed
# Average train loss is 0.4805582782177076:
# Average validation loss is 0.5833770407212747
# Average validation dice coef is 0.4166229592787253
# ================================================================================
# Epoch:  34 Batch:  0 Current Loss:  0.5481950044631958
# Epoch:  34 Batch:  100 Current Loss:  0.6877739429473877
# ================================================================================
# Epoch 34 completed
# Average train loss is 0.45313183534635254:
# Average validation loss is 0.608693050371634
# Average validation dice coef is 0.391306949628366
# ================================================================================
# Epoch:  35 Batch:  0 Current Loss:  0.8512529730796814
# Epoch:  35 Batch:  100 Current Loss:  0.23786789178848267
# ================================================================================
# Epoch 35 completed
# Average train loss is 0.4537804539073004:
# Average validation loss is 0.5244307807973914
# Average validation dice coef is 0.47556921920260864
# ================================================================================
# Epoch:  36 Batch:  0 Current Loss:  0.6940456032752991
# Epoch:  36 Batch:  100 Current Loss:  0.3349243998527527
# ================================================================================
# Epoch 36 completed
# Average train loss is 0.4630965174060978:
# Average validation loss is 0.5340902273719376
# Average validation dice coef is 0.46590977262806244
# ================================================================================
# Epoch:  37 Batch:  0 Current Loss:  0.5126712322235107
# Epoch:  37 Batch:  100 Current Loss:  0.9809908270835876
# ================================================================================
# Epoch 37 completed
# Average train loss is 0.46900526423976846:
# Average validation loss is 0.5699301362037659
# Average validation dice coef is 0.43006986379623413
# ================================================================================
# Epoch:  38 Batch:  0 Current Loss:  0.30367350578308105
# Epoch:  38 Batch:  100 Current Loss:  0.26626771688461304
# ================================================================================
# Epoch 38 completed
# Average train loss is 0.4415001232330113:
# Average validation loss is 0.5386085590800723
# Average validation dice coef is 0.4613914409199277
# ================================================================================
# Epoch:  39 Batch:  0 Current Loss:  0.4750250577926636
# Epoch:  39 Batch:  100 Current Loss:  0.24449574947357178
# ================================================================================
# Epoch 39 completed
# Average train loss is 0.45821586986110635:
# Average validation loss is 0.5833854159793338
# Average validation dice coef is 0.4166145840206662
# ================================================================================
# Epoch:  40 Batch:  0 Current Loss:  0.8777667284011841
# Epoch:  40 Batch:  100 Current Loss:  0.4387597441673279
# ================================================================================
# Epoch 40 completed
# Average train loss is 0.43061538755077206:
# Average validation loss is 0.5546886534304232
# Average validation dice coef is 0.4453113465695768
# ================================================================================
# Epoch:  41 Batch:  0 Current Loss:  0.3181365728378296
# Epoch:  41 Batch:  100 Current Loss:  0.23082226514816284
# ================================================================================
# Epoch 41 completed
# Average train loss is 0.4314684859693867:
# Average validation loss is 0.6039345183887997
# Average validation dice coef is 0.39606548161120025
# ================================================================================
# Epoch:  42 Batch:  0 Current Loss:  0.32223308086395264
# Epoch:  42 Batch:  100 Current Loss:  0.6535371541976929
# ================================================================================
# Epoch 42 completed
# Average train loss is 0.4370340700835398:
# Average validation loss is 0.6035145907788664
# Average validation dice coef is 0.3964854092211336
# ================================================================================
# Epoch:  43 Batch:  0 Current Loss:  0.4127926826477051
# Epoch:  43 Batch:  100 Current Loss:  0.7813705801963806
# ================================================================================
# Epoch 43 completed
# Average train loss is 0.4357984253804978:
# Average validation loss is 0.6404427596040674
# Average validation dice coef is 0.3595572403959326
# ================================================================================
# Epoch:  44 Batch:  0 Current Loss:  0.21612775325775146
# Epoch:  44 Batch:  100 Current Loss:  0.3769562840461731
# ================================================================================
# Epoch 44 completed
# Average train loss is 0.4395336529163465:
# Average validation loss is 0.5084356891142355
# Average validation dice coef is 0.49156431088576447
# ================================================================================
# Epoch:  45 Batch:  0 Current Loss:  0.38183218240737915
# Epoch:  45 Batch:  100 Current Loss:  0.5615575909614563
# ================================================================================
# Epoch 45 completed
# Average train loss is 0.4231540360679365:
# Average validation loss is 0.577519822765041
# Average validation dice coef is 0.422480177234959
# ================================================================================
# Epoch:  46 Batch:  0 Current Loss:  0.3615293502807617
# Epoch:  46 Batch:  100 Current Loss:  0.5573388338088989
# ================================================================================
# Epoch 46 completed
# Average train loss is 0.4319242973850198:
# Average validation loss is 0.5388328658567892
# Average validation dice coef is 0.46116713414321076
# ================================================================================
# Epoch:  47 Batch:  0 Current Loss:  0.5567408800125122
# Epoch:  47 Batch:  100 Current Loss:  0.3841307759284973
# ================================================================================
# Epoch 47 completed
# Average train loss is 0.44293278374084055:
# Average validation loss is 0.5765912581134487
# Average validation dice coef is 0.4234087418865513
# ================================================================================
# Epoch:  48 Batch:  0 Current Loss:  0.15716230869293213
# Epoch:  48 Batch:  100 Current Loss:  0.31525832414627075
# ================================================================================
# Epoch 48 completed
# Average train loss is 0.40763024026400424:
# Average validation loss is 0.5792272042583775
# Average validation dice coef is 0.4207727957416225
# ================================================================================
# Epoch:  49 Batch:  0 Current Loss:  0.4607948064804077
# Epoch:  49 Batch:  100 Current Loss:  0.4317352771759033
# ================================================================================
# Epoch 49 completed
# Average train loss is 0.43939414130498283:
# Average validation loss is 0.5550126240060136
# Average validation dice coef is 0.4449873759939864
# ================================================================================
# Epoch:  50 Batch:  0 Current Loss:  0.7021628618240356
# Epoch:  50 Batch:  100 Current Loss:  0.3567690849304199
# ================================================================================
# Epoch 50 completed
# Average train loss is 0.41288482775426893:
# Average validation loss is 0.5533562238151962
# Average validation dice coef is 0.4466437761848038
# ================================================================================
# Epoch:  51 Batch:  0 Current Loss:  0.40454548597335815
# Epoch:  51 Batch:  100 Current Loss:  0.17513257265090942
# ================================================================================
# Epoch 51 completed
# Average train loss is 0.4069146922189895:
# Average validation loss is 0.513824145536165
# Average validation dice coef is 0.48617585446383504
# ================================================================================
# Epoch:  52 Batch:  0 Current Loss:  0.1447494626045227
# Epoch:  52 Batch:  100 Current Loss:  0.24175739288330078
# ================================================================================
# Epoch 52 completed
# Average train loss is 0.4189919739553373:
# Average validation loss is 0.5523495545258393
# Average validation dice coef is 0.44765044547416066
# ================================================================================
# Epoch:  53 Batch:  0 Current Loss:  0.26878392696380615
# Epoch:  53 Batch:  100 Current Loss:  0.23508143424987793
# ================================================================================
# Epoch 53 completed
# Average train loss is 0.4347135600161879:
# Average validation loss is 0.5320048896042077
# Average validation dice coef is 0.46799511039579234
# ================================================================================
# Epoch:  54 Batch:  0 Current Loss:  0.4754389524459839
# Epoch:  54 Batch:  100 Current Loss:  0.2987470030784607
# ================================================================================
# Epoch 54 completed
# Average train loss is 0.42384455710241237:
# Average validation loss is 0.5052842078982173
# Average validation dice coef is 0.49471579210178274
# ================================================================================
# Epoch:  55 Batch:  0 Current Loss:  0.4466903805732727
# Epoch:  55 Batch:  100 Current Loss:  0.7155706882476807
# ================================================================================
# Epoch 55 completed
# Average train loss is 0.4088817883844245:
# Average validation loss is 0.5299536183073714
# Average validation dice coef is 0.4700463816926286
# ================================================================================
# Epoch:  56 Batch:  0 Current Loss:  0.18821388483047485
# Epoch:  56 Batch:  100 Current Loss:  0.23168474435806274
# ================================================================================
# Epoch 56 completed
# Average train loss is 0.4068118938027996:
# Average validation loss is 0.5019588840974344
# Average validation dice coef is 0.4980411159025656
# ================================================================================
# Epoch:  57 Batch:  0 Current Loss:  0.4871612787246704
# Epoch:  57 Batch:  100 Current Loss:  0.21774864196777344
# ================================================================================
# Epoch 57 completed
# Average train loss is 0.401003263584555:
# Average validation loss is 0.585872092762509
# Average validation dice coef is 0.41412790723749104
# ================================================================================
# Epoch:  58 Batch:  0 Current Loss:  0.19914978742599487
# Epoch:  58 Batch:  100 Current Loss:  0.665945291519165
# ================================================================================
# Epoch 58 completed
# Average train loss is 0.40508561428279094:
# Average validation loss is 0.5967857161083737
# Average validation dice coef is 0.4032142838916263
# ================================================================================
# Epoch:  59 Batch:  0 Current Loss:  0.23193514347076416
# Epoch:  59 Batch:  100 Current Loss:  0.2431533932685852
# ================================================================================
# Epoch 59 completed
# Average train loss is 0.4171073514304749:
# Average validation loss is 0.5073611768516334
# Average validation dice coef is 0.4926388231483666
# ================================================================================
# Epoch:  60 Batch:  0 Current Loss:  0.2955242395401001
# Epoch:  60 Batch:  100 Current Loss:  0.4390299916267395
# ================================================================================
# Epoch 60 completed
# Average train loss is 0.39678189280914933:
# Average validation loss is 0.5555677317284249
# Average validation dice coef is 0.4444322682715751
# ================================================================================
# Epoch:  61 Batch:  0 Current Loss:  0.5977302193641663
# Epoch:  61 Batch:  100 Current Loss:  0.7879068851470947
# ================================================================================
# Epoch 61 completed
# Average train loss is 0.40303390075082646:
# Average validation loss is 0.5806671880386971
# Average validation dice coef is 0.4193328119613029
# ================================================================================
# Epoch:  62 Batch:  0 Current Loss:  0.18813788890838623
# Epoch:  62 Batch:  100 Current Loss:  0.17702096700668335
# ================================================================================
# Epoch 62 completed
# Average train loss is 0.402380889000958:
# Average validation loss is 0.5266333319045402
# Average validation dice coef is 0.4733666680954598
# ================================================================================
# Epoch:  63 Batch:  0 Current Loss:  0.7606633305549622
# Epoch:  63 Batch:  100 Current Loss:  0.30086129903793335
# ================================================================================
# Epoch 63 completed
# Average train loss is 0.3885603555261272:
# Average validation loss is 0.4827857371923086
# Average validation dice coef is 0.5172142628076914
# ================================================================================
# Epoch:  64 Batch:  0 Current Loss:  0.0905119776725769
# Epoch:  64 Batch:  100 Current Loss:  0.5249786376953125
# ================================================================================
# Epoch 64 completed
# Average train loss is 0.40402143581272804:
# Average validation loss is 0.5117734267904952
# Average validation dice coef is 0.4882265732095048
# ================================================================================
# Epoch:  65 Batch:  0 Current Loss:  0.07653701305389404
# Epoch:  65 Batch:  100 Current Loss:  0.24618321657180786
# ================================================================================
# Epoch 65 completed
# Average train loss is 0.36956606784912005:
# Average validation loss is 0.5413170698526744
# Average validation dice coef is 0.45868293014732564
# ================================================================================
# Epoch:  66 Batch:  0 Current Loss:  0.09561216831207275
# Epoch:  66 Batch:  100 Current Loss:  0.1749347448348999
# ================================================================================
# Epoch 66 completed
# Average train loss is 0.4091461717265926:
# Average validation loss is 0.6007474612545323
# Average validation dice coef is 0.39925253874546773
# ================================================================================
# Epoch:  67 Batch:  0 Current Loss:  0.22288399934768677
# Epoch:  67 Batch:  100 Current Loss:  0.3348805904388428
# ================================================================================
# Epoch 67 completed
# Average train loss is 0.40201650172063746:
# Average validation loss is 0.4926274434940235
# Average validation dice coef is 0.5073725565059766
# ================================================================================
# Epoch:  68 Batch:  0 Current Loss:  0.35049498081207275
# Epoch:  68 Batch:  100 Current Loss:  0.15277791023254395
# ================================================================================
# Epoch 68 completed
# Average train loss is 0.3810205451429707:
# Average validation loss is 0.48895160088668
# Average validation dice coef is 0.51104839911332
# ================================================================================
# Epoch:  69 Batch:  0 Current Loss:  0.5632200241088867
# Epoch:  69 Batch:  100 Current Loss:  0.5275959968566895
# ================================================================================
# Epoch 69 completed
# Average train loss is 0.38644373335250437:
# Average validation loss is 0.5077623434968896
# Average validation dice coef is 0.49223765650311035
# ================================================================================
# Epoch:  70 Batch:  0 Current Loss:  0.17259961366653442
# Epoch:  70 Batch:  100 Current Loss:  0.34059005975723267
# ================================================================================
# Epoch 70 completed
# Average train loss is 0.38247986035804227:
# Average validation loss is 0.5277714149371998
# Average validation dice coef is 0.4722285850628002
# ================================================================================
# Epoch:  71 Batch:  0 Current Loss:  0.3885490894317627
# Epoch:  71 Batch:  100 Current Loss:  0.12165433168411255
# ================================================================================
# Epoch 71 completed
# Average train loss is 0.3730029271890039:
# Average validation loss is 0.6192273916424932
# Average validation dice coef is 0.3807726083575068
# ================================================================================
# Epoch:  72 Batch:  0 Current Loss:  0.9940424561500549
# Epoch:  72 Batch:  100 Current Loss:  0.24099856615066528
# ================================================================================
# Epoch 72 completed
# Average train loss is 0.397341057045819:
# Average validation loss is 0.5930050240980612
# Average validation dice coef is 0.4069949759019388
# ================================================================================
# Epoch:  73 Batch:  0 Current Loss:  0.5124866962432861
# Epoch:  73 Batch:  100 Current Loss:  0.4526195526123047
# ================================================================================
# Epoch 73 completed
# Average train loss is 0.3754641205480654:
# Average validation loss is 0.4623034435349542
# Average validation dice coef is 0.5376965564650458
# ================================================================================
# Epoch:  74 Batch:  0 Current Loss:  0.4319545030593872
# Epoch:  74 Batch:  100 Current Loss:  0.5585588216781616
# ================================================================================
# Epoch 74 completed
# Average train loss is 0.3706340695897194:
# Average validation loss is 0.5396403847513972
# Average validation dice coef is 0.4603596152486028
# ================================================================================
# Epoch:  75 Batch:  0 Current Loss:  0.34613555669784546
# Epoch:  75 Batch:  100 Current Loss:  0.20147770643234253
# ================================================================================
# Epoch 75 completed
# Average train loss is 0.36553283709369294:
# Average validation loss is 0.5737464556822905
# Average validation dice coef is 0.42625354431770945
# ================================================================================
# Epoch:  76 Batch:  0 Current Loss:  0.2074575424194336
# Epoch:  76 Batch:  100 Current Loss:  0.1478399634361267
# ================================================================================
# Epoch 76 completed
# Average train loss is 0.3716576295356228:
# Average validation loss is 0.4955798999683277
# Average validation dice coef is 0.5044201000316724
# ================================================================================
# Epoch:  77 Batch:  0 Current Loss:  0.7477067112922668
# Epoch:  77 Batch:  100 Current Loss:  0.08071303367614746
# ================================================================================
# Epoch 77 completed
# Average train loss is 0.3756246799475526:
# Average validation loss is 0.5472871838389216
# Average validation dice coef is 0.4527128161610784
# ================================================================================
# Epoch:  78 Batch:  0 Current Loss:  0.2283858060836792
# Epoch:  78 Batch:  100 Current Loss:  0.43974244594573975
# ================================================================================
# Epoch 78 completed
# Average train loss is 0.3546704025301215:
# Average validation loss is 0.5922768550950128
# Average validation dice coef is 0.4077231449049872
# ================================================================================
# Epoch:  79 Batch:  0 Current Loss:  0.08082371950149536
# Epoch:  79 Batch:  100 Current Loss:  0.46305692195892334
# ================================================================================
# Epoch 79 completed
# Average train loss is 0.3550164650564324:
# Average validation loss is 0.591974134380753
# Average validation dice coef is 0.40802586561924703
# ================================================================================
# Epoch:  80 Batch:  0 Current Loss:  0.33954185247421265
# Epoch:  80 Batch:  100 Current Loss:  0.2632077932357788
# ================================================================================
# Epoch 80 completed
# Average train loss is 0.3617155923418803:
# Average validation loss is 0.49745763636924123
# Average validation dice coef is 0.5025423636307588
# ================================================================================
# Epoch:  81 Batch:  0 Current Loss:  0.20631057024002075
# Epoch:  81 Batch:  100 Current Loss:  0.25023984909057617
# ================================================================================
# Epoch 81 completed
# Average train loss is 0.37623750224505387:
# Average validation loss is 0.45308879098376714
# Average validation dice coef is 0.5469112090162329
# ================================================================================
# Epoch:  82 Batch:  0 Current Loss:  0.5244861841201782
# Epoch:  82 Batch:  100 Current Loss:  0.17014145851135254
# ================================================================================
# Epoch 82 completed
# Average train loss is 0.35385757521407246:
# Average validation loss is 0.5153046508093138
# Average validation dice coef is 0.48469534919068624
# ================================================================================
# Epoch:  83 Batch:  0 Current Loss:  0.19881856441497803
# Epoch:  83 Batch:  100 Current Loss:  0.23098421096801758
# ================================================================================
# Epoch 83 completed
# Average train loss is 0.37005616010051884:
# Average validation loss is 0.5322665411072809
# Average validation dice coef is 0.4677334588927191
# ================================================================================
# Epoch:  84 Batch:  0 Current Loss:  0.20996832847595215
# Epoch:  84 Batch:  100 Current Loss:  0.2728419899940491
# ================================================================================
# Epoch 84 completed
# Average train loss is 0.33960526283473186:
# Average validation loss is 0.50599245606242
# Average validation dice coef is 0.49400754393757995
# ================================================================================
# Epoch:  85 Batch:  0 Current Loss:  0.2830936908721924
# Epoch:  85 Batch:  100 Current Loss:  0.7187994718551636
# ================================================================================
# Epoch 85 completed
# Average train loss is 0.3292475942879507:
# Average validation loss is 0.5037198952726416
# Average validation dice coef is 0.4962801047273584
# ================================================================================
# Epoch:  86 Batch:  0 Current Loss:  0.15531319379806519
# Epoch:  86 Batch:  100 Current Loss:  0.7515462040901184
# ================================================================================
# Epoch 86 completed
# Average train loss is 0.3397762228364814:
# Average validation loss is 0.4945123791694641
# Average validation dice coef is 0.5054876208305359
# ================================================================================
# Epoch:  87 Batch:  0 Current Loss:  0.20162683725357056
# Epoch:  87 Batch:  100 Current Loss:  0.3312373757362366
# ================================================================================
# Epoch 87 completed
# Average train loss is 0.3449237665084943:
# Average validation loss is 0.4966191665546314
# Average validation dice coef is 0.5033808334453687
# ================================================================================
# Epoch:  88 Batch:  0 Current Loss:  0.2069208025932312
# Epoch:  88 Batch:  100 Current Loss:  0.10611450672149658
# ================================================================================
# Epoch 88 completed
# Average train loss is 0.33933668961263685:
# Average validation loss is 0.49028052671535594
# Average validation dice coef is 0.5097194732846441
# ================================================================================
# Epoch:  89 Batch:  0 Current Loss:  0.6930131912231445
# Epoch:  89 Batch:  100 Current Loss:  0.2141476273536682
# ================================================================================
# Epoch 89 completed
# Average train loss is 0.32956047621491835:
# Average validation loss is 0.48488109981691513
# Average validation dice coef is 0.5151189001830849
# ================================================================================
# Epoch:  90 Batch:  0 Current Loss:  0.10053813457489014
# Epoch:  90 Batch:  100 Current Loss:  0.3670883774757385
# ================================================================================
# Epoch 90 completed
# Average train loss is 0.3355411981066612:
# Average validation loss is 0.44255314807634094
# Average validation dice coef is 0.5574468519236591
# ================================================================================
# Epoch:  91 Batch:  0 Current Loss:  0.2387790083885193
# Epoch:  91 Batch:  100 Current Loss:  0.3167569637298584
# ================================================================================
# Epoch 91 completed
# Average train loss is 0.3250760260510118:
# Average validation loss is 0.4820900639972171
# Average validation dice coef is 0.5179099360027829
# ================================================================================
# Epoch:  92 Batch:  0 Current Loss:  0.4823864698410034
# Epoch:  92 Batch:  100 Current Loss:  0.20057833194732666
# ================================================================================
# Epoch 92 completed
# Average train loss is 0.34810344936096504:
# Average validation loss is 0.5340634101145977
# Average validation dice coef is 0.4659365898854023
# ================================================================================
# Epoch:  93 Batch:  0 Current Loss:  0.17196285724639893
# Epoch:  93 Batch:  100 Current Loss:  0.3892163634300232
# ================================================================================
# Epoch 93 completed
# Average train loss is 0.3354692826532338:
# Average validation loss is 0.5119834542274475
# Average validation dice coef is 0.4880165457725525
# ================================================================================
# Epoch:  94 Batch:  0 Current Loss:  0.193015456199646
# Epoch:  94 Batch:  100 Current Loss:  0.3836996555328369
# ================================================================================
# Epoch 94 completed
# Average train loss is 0.33115217375428707:
# Average validation loss is 0.4960469281351244
# Average validation dice coef is 0.5039530718648756
# ================================================================================
# Epoch:  95 Batch:  0 Current Loss:  0.5840118527412415
# Epoch:  95 Batch:  100 Current Loss:  0.34198999404907227
# ================================================================================
# Epoch 95 completed
# Average train loss is 0.3164128604000562:
# Average validation loss is 0.48014092123186264
# Average validation dice coef is 0.5198590787681374
# ================================================================================
# Epoch:  96 Batch:  0 Current Loss:  0.2442619800567627
# Epoch:  96 Batch:  100 Current Loss:  0.18121296167373657
# ================================================================================
# Epoch 96 completed
# Average train loss is 0.3316585094961402:
# Average validation loss is 0.49329770739014084
# Average validation dice coef is 0.5067022926098592
# ================================================================================
# Epoch:  97 Batch:  0 Current Loss:  0.5246976613998413
# Epoch:  97 Batch:  100 Current Loss:  0.22244000434875488
# ================================================================================
# Epoch 97 completed
# Average train loss is 0.308769698420616:
# Average validation loss is 0.5247517550313795
# Average validation dice coef is 0.4752482449686205
# ================================================================================
# Epoch:  98 Batch:  0 Current Loss:  0.16117233037948608
# Epoch:  98 Batch:  100 Current Loss:  0.2298944592475891
# ================================================================================
# Epoch 98 completed
# Average train loss is 0.3323665922635222:
# Average validation loss is 0.4737873931188841
# Average validation dice coef is 0.5262126068811159
# ================================================================================
# Epoch:  99 Batch:  0 Current Loss:  0.3647979497909546
# Epoch:  99 Batch:  100 Current Loss:  0.1337066888809204
# ================================================================================
# Epoch 99 completed
# Average train loss is 0.31691765213665896:
# Average validation loss is 0.5433725038090268
# Average validation dice coef is 0.4566274961909732
# ================================================================================
# Epoch:  100 Batch:  0 Current Loss:  0.10766744613647461
# Epoch:  100 Batch:  100 Current Loss:  0.12492913007736206
# ================================================================================
# Epoch 100 completed
# Average train loss is 0.33130714868846006:
# Average validation loss is 0.48028881002116847
# Average validation dice coef is 0.5197111899788316
# ================================================================================
# Highest validation dice score: 0.5574468519236591 at epoch 90

# %%
#############################Dice with Focal Function

epochs = 100


train_running_loss_history = []
validation_running_loss_history =[]
dice_coeff_dicewithfocal=[]

for e in range(epochs):
  dice_loss=0.0
  train_running_loss = 0.0
  validation_running_loss = 0.0
  
  model.train()
  
  for ith_batch, sample_batched in enumerate(train_loader):
    X_train = sample_batched['image'].to('cuda')
    y_train = sample_batched['gt'].to('cuda')

    optimizer.zero_grad()
    y_pred = model(X_train)
    #out = (y_pred + 0.5).int().float()
    
    #loss = FocalLoss()(y_pred,y_train)/N-torch.log(DiceLoss()(y_pred,y_train))
    #loss = criterion(y_pred, y_train)
    loss =0.5*DiceLoss()(y_pred,y_train.float())+0.5*FocalLoss()(y_pred,y_train.float())
    loss.backward()
    optimizer.step()
    
    if ith_batch % 100 == 0:
      print('Epoch: ', e + 1, 'Batch: ', ith_batch, 'Current Loss: ', loss.item())
      
    train_running_loss += loss.item()




 ###### Validation  
  else:
    with torch.no_grad(): 
      model.eval()
      for ith_batch, sample_batched in enumerate(validation_loader):
          X_val = sample_batched['image'].to('cuda')
          y_val = sample_batched['gt'].to('cuda')
          y_pred = model(X_val)
          #out_val = (y_out + 0.5).int().float()        
          val_loss = 0.5*DiceLoss()(y_pred,y_val.float())+0.5*FocalLoss()(y_pred,y_val.float())
          dicel=DiceLoss()(y_pred, y_val)
          validation_running_loss += val_loss.item()
          dice_loss+=dicel.item()
  if (e+1)%10==0:
    torch.save({'model_state_dict':model.state_dict(), 
                'epoch':e,
                'optimizer_state_dict':optimizer.state_dict(),
                'loss':loss.item()}, "/content/gdrive/MyDrive/Stroke/bs_2_ehl_epoch{}".format(e+1))


 #########################Print error         

  print("================================================================================")
  print("Epoch {} completed".format(e + 1))
      
  train_epoch_loss = train_running_loss / len(train_loader)
  validation_epoch_loss = validation_running_loss / len(validation_loader)
  valid_dice_score=1-dice_loss/len(validation_loader)    
  print("Average train loss is {}: ".format(train_epoch_loss))
  print("Average validation loss is {}".format(validation_epoch_loss))
  print("Average validation dice coef is {}".format(valid_dice_score))

  print("================================================================================")
  train_running_loss_history.append(train_epoch_loss)
  validation_running_loss_history.append(validation_epoch_loss)
  dice_coeff_dicewithfocal.append(valid_dice_score)

torch.cuda.empty_cache()

plt.plot(train_running_loss_history, label = 'Train Loss')
plt.plot(validation_running_loss_history, label = 'Validation Loss')
plt.legend()
plt.title("Train and valid Loss")
plt.ylabel("Loss")
plt.xlabel("Epochs")
max_dice_coef=max(dice_coeff_dicewithfocal)
index=np.argmax(dice_coeff_dicewithfocal)+1
print("Highest validation dice score: {} at epoch {} ".format(max_dice_coef,index))
# Out:
# Epoch:  1 Batch:  0 Current Loss:  0.9344019889831543
# Epoch:  1 Batch:  100 Current Loss:  0.4806900918483734
# ================================================================================
# Epoch 1 completed
# Average train loss is 0.541377355791118:
# Average validation loss is 0.46752335815816315
# Average validation dice coef is 0.11704506745209564
# ================================================================================
# Epoch:  2 Batch:  0 Current Loss:  0.37557199597358704
# Epoch:  2 Batch:  100 Current Loss:  0.5134713649749756
# ================================================================================
# Epoch 2 completed
# Average train loss is 0.4281657353451807:
# Average validation loss is 0.4233712843946508
# Average validation dice coef is 0.18145173304789775
# ================================================================================
# Epoch:  3 Batch:  0 Current Loss:  0.5114182829856873
# Epoch:  3 Batch:  100 Current Loss:  0.3073985278606415
# ================================================================================
# Epoch 3 completed
# Average train loss is 0.3792333454914289:
# Average validation loss is 0.36164137761335113
# Average validation dice coef is 0.29711271137804596
# ================================================================================
# Epoch:  4 Batch:  0 Current Loss:  0.4336809515953064
# Epoch:  4 Batch:  100 Current Loss:  0.21032333374023438
# ================================================================================
# Epoch 4 completed
# Average train loss is 0.33927623386660666:
# Average validation loss is 0.3439124383636423
# Average validation dice coef is 0.32909523152016307
# ================================================================================
# Epoch:  5 Batch:  0 Current Loss:  0.4733978807926178
# Epoch:  5 Batch:  100 Current Loss:  0.13840068876743317
# ================================================================================
# Epoch 5 completed
# Average train loss is 0.3138543219905194:
# Average validation loss is 0.3554918371342324
# Average validation dice coef is 0.30582015095530335
# ================================================================================
# Epoch:  6 Batch:  0 Current Loss:  0.2701027989387512
# Epoch:  6 Batch:  100 Current Loss:  0.47547122836112976
# ================================================================================
# Epoch 6 completed
# Average train loss is 0.2947700242575717:
# Average validation loss is 0.33883846692136815
# Average validation dice coef is 0.33947497606277466
# ================================================================================
# Epoch:  7 Batch:  0 Current Loss:  0.23020052909851074
# Epoch:  7 Batch:  100 Current Loss:  0.42722252011299133
# ================================================================================
# Epoch 7 completed
# Average train loss is 0.2767197896968828:
# Average validation loss is 0.32583629662120667
# Average validation dice coef is 0.36652690172195435
# ================================================================================
# Epoch:  8 Batch:  0 Current Loss:  0.2965138256549835
# Epoch:  8 Batch:  100 Current Loss:  0.15472085773944855
# ================================================================================
# Epoch 8 completed
# Average train loss is 0.27600316101149336:
# Average validation loss is 0.3293209625659762
# Average validation dice coef is 0.36029595297736094
# ================================================================================
# Epoch:  9 Batch:  0 Current Loss:  0.24266280233860016
# Epoch:  9 Batch:  100 Current Loss:  0.3125778138637543
# ================================================================================
# Epoch 9 completed
# Average train loss is 0.2592160048550122:
# Average validation loss is 0.32396440801991
# Average validation dice coef is 0.3707584513200296
# ================================================================================
# Epoch:  10 Batch:  0 Current Loss:  0.16380904614925385
# Epoch:  10 Batch:  100 Current Loss:  0.27594301104545593
# ================================================================================
# Epoch 10 completed
# Average train loss is 0.25889056824045636:
# Average validation loss is 0.2976113545733529
# Average validation dice coef is 0.4222101746378718
# ================================================================================
# Epoch:  11 Batch:  0 Current Loss:  0.17452675104141235
# Epoch:  11 Batch:  100 Current Loss:  0.10861175507307053
# ================================================================================
# Epoch 11 completed
# Average train loss is 0.2476311511270804:
# Average validation loss is 0.2865036816613094
# Average validation dice coef is 0.4508425383954435
# ================================================================================
# Epoch:  12 Batch:  0 Current Loss:  0.1701260805130005
# Epoch:  12 Batch:  100 Current Loss:  0.10563994944095612
# ================================================================================
# Epoch 12 completed
# Average train loss is 0.25337085109969526:
# Average validation loss is 0.3024245685822255
# Average validation dice coef is 0.41543902094299734
# ================================================================================
# Epoch:  13 Batch:  0 Current Loss:  0.4409118592739105
# Epoch:  13 Batch:  100 Current Loss:  0.14693015813827515
# ================================================================================
# Epoch 13 completed
# Average train loss is 0.26499401635094866:
# Average validation loss is 0.27555990178842804
# Average validation dice coef is 0.47169363337594106
# ================================================================================
# Epoch:  14 Batch:  0 Current Loss:  0.47412610054016113
# Epoch:  14 Batch:  100 Current Loss:  0.1506798267364502
# ================================================================================
# Epoch 14 completed
# Average train loss is 0.24875776127797283:
# Average validation loss is 0.31241583159646474
# Average validation dice coef is 0.3946935598914688
# ================================================================================
# Epoch:  15 Batch:  0 Current Loss:  0.13756199181079865
# Epoch:  15 Batch:  100 Current Loss:  0.17187418043613434
# ================================================================================
# Epoch 15 completed
# Average train loss is 0.25419035041066884:
# Average validation loss is 0.3033133733111459
# Average validation dice coef is 0.4143612851967683
# ================================================================================
# Epoch:  16 Batch:  0 Current Loss:  0.2672267258167267
# Epoch:  16 Batch:  100 Current Loss:  0.45853865146636963
# ================================================================================
# Epoch 16 completed
# Average train loss is 0.2472091918326404:
# Average validation loss is 0.2985588962564597
# Average validation dice coef is 0.4250137048798639
# ================================================================================
# Epoch:  17 Batch:  0 Current Loss:  0.20171013474464417
# Epoch:  17 Batch:  100 Current Loss:  0.1143922209739685
# ================================================================================
# Epoch 17 completed
# Average train loss is 0.2449348386479159:
# Average validation loss is 0.29912789971441833
# Average validation dice coef is 0.42082421360789124
# ================================================================================
# Epoch:  18 Batch:  0 Current Loss:  0.14486733078956604
# Epoch:  18 Batch:  100 Current Loss:  0.25403499603271484
# ================================================================================
# Epoch 18 completed
# Average train loss is 0.2399811965145477:
# Average validation loss is 0.3007804278183628
# Average validation dice coef is 0.42096875648240784
# ================================================================================
# Epoch:  19 Batch:  0 Current Loss:  0.4171426594257355
# Epoch:  19 Batch:  100 Current Loss:  0.10711441934108734
# ================================================================================
# Epoch 19 completed
# Average train loss is 0.24689766943250616:
# Average validation loss is 0.3071265697881982
# Average validation dice coef is 0.41491220931749084
# ================================================================================
# Epoch:  20 Batch:  0 Current Loss:  0.2887905240058899
# Epoch:  20 Batch:  100 Current Loss:  0.48041969537734985
# ================================================================================
# Epoch 20 completed
# Average train loss is 0.24627754696938273:
# Average validation loss is 0.3092674316989409
# Average validation dice coef is 0.40441074081369344
# ================================================================================
# Epoch:  21 Batch:  0 Current Loss:  0.2869757413864136
# Epoch:  21 Batch:  100 Current Loss:  0.3726324141025543
# ================================================================================
# Epoch 21 completed
# Average train loss is 0.2355950235401931:
# Average validation loss is 0.32400001887534113
# Average validation dice coef is 0.3781458429388098
# ================================================================================
# Epoch:  22 Batch:  0 Current Loss:  0.10901536047458649
# Epoch:  22 Batch:  100 Current Loss:  0.12959504127502441
# ================================================================================
# Epoch 22 completed
# Average train loss is 0.23175461227967314:
# Average validation loss is 0.32063872840356183
# Average validation dice coef is 0.3797463887446636
# ================================================================================
# Epoch:  23 Batch:  0 Current Loss:  0.09663628041744232
# Epoch:  23 Batch:  100 Current Loss:  0.4905434250831604
# ================================================================================
# Epoch 23 completed
# Average train loss is 0.2558872886512378:
# Average validation loss is 0.28157453037597036
# Average validation dice coef is 0.4565387803155023
# ================================================================================
# Epoch:  24 Batch:  0 Current Loss:  0.36612409353256226
# Epoch:  24 Batch:  100 Current Loss:  0.08932610601186752
# ================================================================================
# Epoch 24 completed
# Average train loss is 0.2319261303860439:
# Average validation loss is 0.30536292493343353
# Average validation dice coef is 0.4093006962054485
# ================================================================================
# Epoch:  25 Batch:  0 Current Loss:  0.18189966678619385
# Epoch:  25 Batch:  100 Current Loss:  0.16825756430625916
# ================================================================================
# Epoch 25 completed
# Average train loss is 0.23971409401664995:
# Average validation loss is 0.33785919361823313
# Average validation dice coef is 0.34663218581998667
# ================================================================================
# Epoch:  26 Batch:  0 Current Loss:  0.3739416301250458
# Epoch:  26 Batch:  100 Current Loss:  0.18563146889209747
# ================================================================================
# Epoch 26 completed
# Average train loss is 0.2445027406697404:
# Average validation loss is 0.3229293126512218
# Average validation dice coef is 0.37618899023210683
# ================================================================================
# Epoch:  27 Batch:  0 Current Loss:  0.20870590209960938
# Epoch:  27 Batch:  100 Current Loss:  0.31441420316696167
# ================================================================================
# Epoch 27 completed
# Average train loss is 0.2295500422279312:
# Average validation loss is 0.2951485122981909
# Average validation dice coef is 0.42823437420097554
# ================================================================================
# Epoch:  28 Batch:  0 Current Loss:  0.13332334160804749
# Epoch:  28 Batch:  100 Current Loss:  0.13985665142536163
# ================================================================================
# Epoch 28 completed
# Average train loss is 0.22289598812285352:
# Average validation loss is 0.28500980360282435
# Average validation dice coef is 0.44999340579316427
# ================================================================================
# Epoch:  29 Batch:  0 Current Loss:  0.17805124819278717
# Epoch:  29 Batch:  100 Current Loss:  0.25231751799583435
# ================================================================================
# Epoch 29 completed
# Average train loss is 0.2270130446206217:
# Average validation loss is 0.29467351362109184
# Average validation dice coef is 0.43282294112282826
# ================================================================================
# Epoch:  30 Batch:  0 Current Loss:  0.05010885000228882
# Epoch:  30 Batch:  100 Current Loss:  0.2029660940170288
# ================================================================================
# Epoch 30 completed
# Average train loss is 0.22489040176550004:
# Average validation loss is 0.3049065615679767
# Average validation dice coef is 0.4131298484028997
# ================================================================================
# Epoch:  31 Batch:  0 Current Loss:  0.18519768118858337
# Epoch:  31 Batch:  100 Current Loss:  0.49132874608039856
# ================================================================================
# Epoch 31 completed
# Average train loss is 0.22285434249023053:
# Average validation loss is 0.2931476666315182
# Average validation dice coef is 0.4342525665824478
# ================================================================================
# Epoch:  32 Batch:  0 Current Loss:  0.2593832314014435
# Epoch:  32 Batch:  100 Current Loss:  0.13514763116836548
# ================================================================================
# Epoch 32 completed
# Average train loss is 0.22245312724517632:
# Average validation loss is 0.3193552082253469
# Average validation dice coef is 0.38645575175414215
# ================================================================================
# Epoch:  33 Batch:  0 Current Loss:  0.22171150147914886
# Epoch:  33 Batch:  100 Current Loss:  0.1217200830578804
# ================================================================================
# Epoch 33 completed
# Average train loss is 0.2192021226637984:
# Average validation loss is 0.27885490867334445
# Average validation dice coef is 0.4652949313859682
# ================================================================================
# Epoch:  34 Batch:  0 Current Loss:  0.5081853270530701
# Epoch:  34 Batch:  100 Current Loss:  0.14136461913585663
# ================================================================================
# Epoch 34 completed
# Average train loss is 0.21778040318048164:
# Average validation loss is 0.31642683615555633
# Average validation dice coef is 0.3892300579998944
# ================================================================================
# Epoch:  35 Batch:  0 Current Loss:  0.21736732125282288
# Epoch:  35 Batch:  100 Current Loss:  0.2553130090236664
# ================================================================================
# Epoch 35 completed
# Average train loss is 0.21675848680203907:
# Average validation loss is 0.29624800222951014
# Average validation dice coef is 0.43066939792117553
# ================================================================================
# Epoch:  36 Batch:  0 Current Loss:  0.28279784321784973
# Epoch:  36 Batch:  100 Current Loss:  0.15814930200576782
# ================================================================================
# Epoch 36 completed
# Average train loss is 0.22115582937043007:
# Average validation loss is 0.2899354333813126
# Average validation dice coef is 0.4398456505827002
# ================================================================================
# Epoch:  37 Batch:  0 Current Loss:  0.2799471914768219
# Epoch:  37 Batch:  100 Current Loss:  0.2040633261203766
# ================================================================================
# Epoch 37 completed
# Average train loss is 0.20755618221241318:
# Average validation loss is 0.3085909346873696
# Average validation dice coef is 0.40543900309382264
# ================================================================================
# Epoch:  38 Batch:  0 Current Loss:  0.2503086030483246
# Epoch:  38 Batch:  100 Current Loss:  0.2265518605709076
# ================================================================================
# Epoch 38 completed
# Average train loss is 0.21744536067525003:
# Average validation loss is 0.2862407979932991
# Average validation dice coef is 0.4477684417286435
# ================================================================================
# Epoch:  39 Batch:  0 Current Loss:  0.43519002199172974
# Epoch:  39 Batch:  100 Current Loss:  0.37910234928131104
# ================================================================================
# Epoch 39 completed
# Average train loss is 0.20963067497598797:
# Average validation loss is 0.28332310914993286
# Average validation dice coef is 0.4537937383393984
# ================================================================================
# Epoch:  40 Batch:  0 Current Loss:  0.3657575845718384
# Epoch:  40 Batch:  100 Current Loss:  0.11268205940723419
# ================================================================================
# Epoch 40 completed
# Average train loss is 0.21218707733978964:
# Average validation loss is 0.3143404496682657
# Average validation dice coef is 0.4038548485652821
# ================================================================================
# Epoch:  41 Batch:  0 Current Loss:  0.2597198486328125
# Epoch:  41 Batch:  100 Current Loss:  0.0756949633359909
# ================================================================================
# Epoch 41 completed
# Average train loss is 0.2096027277205905:
# Average validation loss is 0.26744159250646027
# Average validation dice coef is 0.48214107590752675
# ================================================================================
# Epoch:  42 Batch:  0 Current Loss:  0.14194342494010925
# Epoch:  42 Batch:  100 Current Loss:  0.31682783365249634
# ================================================================================
# Epoch 42 completed
# Average train loss is 0.2095262819314248:
# Average validation loss is 0.3054932204855455
# Average validation dice coef is 0.41282366256456116
# ================================================================================
# Epoch:  43 Batch:  0 Current Loss:  0.2480221837759018
# Epoch:  43 Batch:  100 Current Loss:  0.09175615757703781
# ================================================================================
# Epoch 43 completed
# Average train loss is 0.20235923519485619:
# Average validation loss is 0.3150242124054883
# Average validation dice coef is 0.3900435438027253
# ================================================================================
# Epoch:  44 Batch:  0 Current Loss:  0.37109094858169556
# Epoch:  44 Batch:  100 Current Loss:  0.12366781383752823
# ================================================================================
# Epoch 44 completed
# Average train loss is 0.1906040095507282:
# Average validation loss is 0.3296334906607061
# Average validation dice coef is 0.3695563899504172
# ================================================================================
# Epoch:  45 Batch:  0 Current Loss:  0.07770663499832153
# Epoch:  45 Batch:  100 Current Loss:  0.05845656245946884
# ================================================================================
# Epoch 45 completed
# Average train loss is 0.1942376213735097:
# Average validation loss is 0.2842016802043528
# Average validation dice coef is 0.4515362253060212
# ================================================================================
# Epoch:  46 Batch:  0 Current Loss:  0.16979500651359558
# Epoch:  46 Batch:  100 Current Loss:  0.36961856484413147
# ================================================================================
# Epoch 46 completed
# Average train loss is 0.20460984947746746:
# Average validation loss is 0.2813608808493292
# Average validation dice coef is 0.45952809501338654
# ================================================================================
# Epoch:  47 Batch:  0 Current Loss:  0.21477873623371124
# Epoch:  47 Batch:  100 Current Loss:  0.05638066679239273
# ================================================================================
# Epoch 47 completed
# Average train loss is 0.19081901371070784:
# Average validation loss is 0.30026629365779256
# Average validation dice coef is 0.4231837166322244
# ================================================================================
# Epoch:  48 Batch:  0 Current Loss:  0.06890308856964111
# Epoch:  48 Batch:  100 Current Loss:  0.14773157238960266
# ================================================================================
# Epoch 48 completed
# Average train loss is 0.20166747751709532:
# Average validation loss is 0.30364905811242154
# Average validation dice coef is 0.41536085025684255
# ================================================================================
# Epoch:  49 Batch:  0 Current Loss:  0.24087126553058624
# Epoch:  49 Batch:  100 Current Loss:  0.1043771505355835
# ================================================================================
# Epoch 49 completed
# Average train loss is 0.20401929022922907:
# Average validation loss is 0.29860277614883474
# Average validation dice coef is 0.4263703951964507
# ================================================================================
# Epoch:  50 Batch:  0 Current Loss:  0.1156676858663559
# Epoch:  50 Batch:  100 Current Loss:  0.3566930890083313
# ================================================================================
# Epoch 50 completed
# Average train loss is 0.19853814129960046:
# Average validation loss is 0.2761845023849526
# Average validation dice coef is 0.4704636721997648
# ================================================================================
# Epoch:  51 Batch:  0 Current Loss:  0.509429395198822
# Epoch:  51 Batch:  100 Current Loss:  0.10540398210287094
# ================================================================================
# Epoch 51 completed
# Average train loss is 0.19523359306973137:
# Average validation loss is 0.27975363163529215
# Average validation dice coef is 0.462062255756275
# ================================================================================
# Epoch:  52 Batch:  0 Current Loss:  0.2033134549856186
# Epoch:  52 Batch:  100 Current Loss:  0.16956759989261627
# ================================================================================
# Epoch 52 completed
# Average train loss is 0.18851756784197402:
# Average validation loss is 0.2876165195091351
# Average validation dice coef is 0.4464485290888194
# ================================================================================
# Epoch:  53 Batch:  0 Current Loss:  0.15657368302345276
# Epoch:  53 Batch:  100 Current Loss:  0.09257172793149948
# ================================================================================
# Epoch 53 completed
# Average train loss is 0.1782853599535684:
# Average validation loss is 0.28003671543823705
# Average validation dice coef is 0.4597858351630133
# ================================================================================
# Epoch:  54 Batch:  0 Current Loss:  0.32687216997146606
# Epoch:  54 Batch:  100 Current Loss:  0.0842425674200058
# ================================================================================
# Epoch 54 completed
# Average train loss is 0.1904254511560071:
# Average validation loss is 0.30691300795690435
# Average validation dice coef is 0.4126906797692582
# ================================================================================
# Epoch:  55 Batch:  0 Current Loss:  0.1280006468296051
# Epoch:  55 Batch:  100 Current Loss:  0.18276524543762207
# ================================================================================
# Epoch 55 completed
# Average train loss is 0.1875296299128908:
# Average validation loss is 0.2935771262524901
# Average validation dice coef is 0.4347763593132431
# ================================================================================
# Epoch:  56 Batch:  0 Current Loss:  0.11094885319471359
# Epoch:  56 Batch:  100 Current Loss:  0.21716196835041046
# ================================================================================
# Epoch 56 completed
# Average train loss is 0.18017733158314064:
# Average validation loss is 0.284874294657965
# Average validation dice coef is 0.4519502133936495
# ================================================================================
# Epoch:  57 Batch:  0 Current Loss:  0.07667911052703857
# Epoch:  57 Batch:  100 Current Loss:  0.052194781601428986
# ================================================================================
# Epoch 57 completed
# Average train loss is 0.18478428457595714:
# Average validation loss is 0.2927615100870261
# Average validation dice coef is 0.4372894715618443
# ================================================================================
# Epoch:  58 Batch:  0 Current Loss:  0.17266497015953064
# Epoch:  58 Batch:  100 Current Loss:  0.23372672498226166
# ================================================================================
# Epoch 58 completed
# Average train loss is 0.1699687102937127:
# Average validation loss is 0.29368509734804565
# Average validation dice coef is 0.4370783873506494
# ================================================================================
# Epoch:  59 Batch:  0 Current Loss:  0.3703543543815613
# Epoch:  59 Batch:  100 Current Loss:  0.27480119466781616
# ================================================================================
# Epoch 59 completed
# Average train loss is 0.19811503288068183:
# Average validation loss is 0.29698255184937167
# Average validation dice coef is 0.4297810760704247
# ================================================================================
# Epoch:  60 Batch:  0 Current Loss:  0.36524659395217896
# Epoch:  60 Batch:  100 Current Loss:  0.08902138471603394
# ================================================================================
# Epoch 60 completed
# Average train loss is 0.17609441683512844:
# Average validation loss is 0.3052130341529846
# Average validation dice coef is 0.41195962074640635
# ================================================================================
# Epoch:  61 Batch:  0 Current Loss:  0.20997337996959686
# Epoch:  61 Batch:  100 Current Loss:  0.13431701064109802
# ================================================================================
# Epoch 61 completed
# Average train loss is 0.1692643169160575:
# Average validation loss is 0.32446716745962967
# Average validation dice coef is 0.37804963943120595
# ================================================================================
# Epoch:  62 Batch:  0 Current Loss:  0.06906263530254364
# Epoch:  62 Batch:  100 Current Loss:  0.31788745522499084
# ================================================================================
# Epoch 62 completed
# Average train loss is 0.16938234829943474:
# Average validation loss is 0.30373693861671397
# Average validation dice coef is 0.41509357819686066
# ================================================================================
# Epoch:  63 Batch:  0 Current Loss:  0.2122151106595993
# Epoch:  63 Batch:  100 Current Loss:  0.10758935660123825
# ================================================================================
# Epoch 63 completed
# Average train loss is 0.17962698600165647:
# Average validation loss is 0.2731639726741894
# Average validation dice coef is 0.47974918984078074
# ================================================================================
# Epoch:  64 Batch:  0 Current Loss:  0.12992212176322937
# Epoch:  64 Batch:  100 Current Loss:  0.11690958589315414
# ================================================================================
# Epoch 64 completed
# Average train loss is 0.1698840990254324:
# Average validation loss is 0.29749193696959597
# Average validation dice coef is 0.4270394621668635
# ================================================================================
# Epoch:  65 Batch:  0 Current Loss:  0.10484512895345688
# Epoch:  65 Batch:  100 Current Loss:  0.08608829975128174
# ================================================================================
# Epoch 65 completed
# Average train loss is 0.16146205694810167:
# Average validation loss is 0.27058113185135096
# Average validation dice coef is 0.481809493657705
# ================================================================================
# Epoch:  66 Batch:  0 Current Loss:  0.06707052141427994
# Epoch:  66 Batch:  100 Current Loss:  0.18055309355258942
# ================================================================================
# Epoch 66 completed
# Average train loss is 0.17112140704507697:
# Average validation loss is 0.2759249943333703
# Average validation dice coef is 0.46715320123208537
# ================================================================================
# Epoch:  67 Batch:  0 Current Loss:  0.42045265436172485
# Epoch:  67 Batch:  100 Current Loss:  0.08755744248628616
# ================================================================================
# Epoch 67 completed
# Average train loss is 0.1665677926311754:
# Average validation loss is 0.2844152788858156
# Average validation dice coef is 0.4566150919811146
# ================================================================================
# Epoch:  68 Batch:  0 Current Loss:  0.18135453760623932
# Epoch:  68 Batch:  100 Current Loss:  0.15463726222515106
# ================================================================================
# Epoch 68 completed
# Average train loss is 0.163093784798498:
# Average validation loss is 0.2822349661508122
# Average validation dice coef is 0.46115214599145427
# ================================================================================
# Epoch:  69 Batch:  0 Current Loss:  0.18200327455997467
# Epoch:  69 Batch:  100 Current Loss:  0.06098044291138649
# ================================================================================
# Epoch 69 completed
# Average train loss is 0.15871090436839078:
# Average validation loss is 0.3016865708538004
# Average validation dice coef is 0.42113199749508423
# ================================================================================
# Epoch:  70 Batch:  0 Current Loss:  0.2572227120399475
# Epoch:  70 Batch:  100 Current Loss:  0.08833319693803787
# ================================================================================
# Epoch 70 completed
# Average train loss is 0.1711748308719021:
# Average validation loss is 0.30218033029420954
# Average validation dice coef is 0.42251819211083486
# ================================================================================
# Epoch:  71 Batch:  0 Current Loss:  0.11974350363016129
# Epoch:  71 Batch:  100 Current Loss:  0.12361153960227966
# ================================================================================
# Epoch 71 completed
# Average train loss is 0.1589582576480222:
# Average validation loss is 0.27692904705936844
# Average validation dice coef is 0.47517027564950887
# ================================================================================
# Epoch:  72 Batch:  0 Current Loss:  0.24539102613925934
# Epoch:  72 Batch:  100 Current Loss:  0.20155173540115356
# ================================================================================
# Epoch 72 completed
# Average train loss is 0.15944537734740402:
# Average validation loss is 0.29586170472808787
# Average validation dice coef is 0.4413040683076188
# ================================================================================
# Epoch:  73 Batch:  0 Current Loss:  0.201738640666008
# Epoch:  73 Batch:  100 Current Loss:  0.15848807990550995
# ================================================================================
# Epoch 73 completed
# Average train loss is 0.15981378421595652:
# Average validation loss is 0.3163486968826603
# Average validation dice coef is 0.3947772834752057
# ================================================================================
# Epoch:  74 Batch:  0 Current Loss:  0.08712249994277954
# Epoch:  74 Batch:  100 Current Loss:  0.14679475128650665
# ================================================================================
# Epoch 74 completed
# Average train loss is 0.14974567444663342:
# Average validation loss is 0.28176689963485746
# Average validation dice coef is 0.4640250463743467
# ================================================================================
# Epoch:  75 Batch:  0 Current Loss:  0.3198610544204712
# Epoch:  75 Batch:  100 Current Loss:  0.14893049001693726
# ================================================================================
# Epoch 75 completed
# Average train loss is 0.14642626884048932:
# Average validation loss is 0.4276755707892212
# Average validation dice coef is 0.39856571925652995
# ================================================================================
# Epoch:  76 Batch:  0 Current Loss:  0.06533743441104889
# Epoch:  76 Batch:  100 Current Loss:  0.18336613476276398
# ================================================================================
# Epoch 76 completed
# Average train loss is 0.14756841620762054:
# Average validation loss is 0.29302984657319814
# Average validation dice coef is 0.45357901824487223
# ================================================================================
# Epoch:  77 Batch:  0 Current Loss:  0.10610915720462799
# Epoch:  77 Batch:  100 Current Loss:  0.177358016371727
# ================================================================================
# Epoch 77 completed
# Average train loss is 0.14438851545118306:
# Average validation loss is 0.2756744216422777
# Average validation dice coef is 0.47443362828847524
# ================================================================================
# Epoch:  78 Batch:  0 Current Loss:  0.14383931457996368
# Epoch:  78 Batch:  100 Current Loss:  0.18566849827766418
# ================================================================================
# Epoch 78 completed
# Average train loss is 0.1514827079866847:
# Average validation loss is 0.2862300689558725
# Average validation dice coef is 0.4487827774640676
# ================================================================================
# Epoch:  79 Batch:  0 Current Loss:  0.19741733372211456
# Epoch:  79 Batch:  100 Current Loss:  0.33879515528678894
# ================================================================================
# Epoch 79 completed
# Average train loss is 0.15444027545721564:
# Average validation loss is 0.27596689065968666
# Average validation dice coef is 0.47058270589725393
# ================================================================================
# Epoch:  80 Batch:  0 Current Loss:  0.08237194269895554
# Epoch:  80 Batch:  100 Current Loss:  0.14350558817386627
# ================================================================================
# Epoch 80 completed
# Average train loss is 0.15255881465767343:
# Average validation loss is 0.2991210709552507
# Average validation dice coef is 0.4326233493315207
# ================================================================================
# Epoch:  81 Batch:  0 Current Loss:  0.15330030024051666
# Epoch:  81 Batch:  100 Current Loss:  0.110444076359272
# ================================================================================
# Epoch 81 completed
# Average train loss is 0.15134732397145603:
# Average validation loss is 0.2949117147237868
# Average validation dice coef is 0.43700308735306204
# ================================================================================
# Epoch:  82 Batch:  0 Current Loss:  0.16770675778388977
# Epoch:  82 Batch:  100 Current Loss:  0.1971914917230606
# ================================================================================
# Epoch 82 completed
# Average train loss is 0.14411349798718545:
# Average validation loss is 0.3271858994219754
# Average validation dice coef is 0.374327988237948
# ================================================================================
# Epoch:  83 Batch:  0 Current Loss:  0.08451980352401733
# Epoch:  83 Batch:  100 Current Loss:  0.07796468585729599
# ================================================================================
# Epoch 83 completed
# Average train loss is 0.14895118535687663:
# Average validation loss is 0.3074238560086972
# Average validation dice coef is 0.42541292873588765
# ================================================================================
# Epoch:  84 Batch:  0 Current Loss:  0.17710772156715393
# Epoch:  84 Batch:  100 Current Loss:  0.117078498005867
# ================================================================================
# Epoch 84 completed
# Average train loss is 0.15836419797923468:
# Average validation loss is 0.30827954874650854
# Average validation dice coef is 0.4097656430424871
# ================================================================================
# Epoch:  85 Batch:  0 Current Loss:  0.210890993475914
# Epoch:  85 Batch:  100 Current Loss:  0.11576861143112183
# ================================================================================
# Epoch 85 completed
# Average train loss is 0.14420544723533604:
# Average validation loss is 0.32543772559713674
# Average validation dice coef is 0.3804211954812746
# ================================================================================
# Epoch:  86 Batch:  0 Current Loss:  0.10556148737668991
# Epoch:  86 Batch:  100 Current Loss:  0.19893643260002136
# ================================================================================
# Epoch 86 completed
# Average train loss is 0.13854832894947022:
# Average validation loss is 0.2604740513740359
# Average validation dice coef is 0.5027147032119132
# ================================================================================
# Epoch:  87 Batch:  0 Current Loss:  0.07644567638635635
# Epoch:  87 Batch:  100 Current Loss:  0.07358120381832123
# ================================================================================
# Epoch 87 completed
# Average train loss is 0.1259481948226282:
# Average validation loss is 0.27708456463910436
# Average validation dice coef is 0.47196020790048543
# ================================================================================
# Epoch:  88 Batch:  0 Current Loss:  0.10733229666948318
# Epoch:  88 Batch:  100 Current Loss:  0.09424522519111633
# ================================================================================
# Epoch 88 completed
# Average train loss is 0.13946245159086298:
# Average validation loss is 0.29784492040808136
# Average validation dice coef is 0.42746805500339813
# ================================================================================
# Epoch:  89 Batch:  0 Current Loss:  0.07059802114963531
# Epoch:  89 Batch:  100 Current Loss:  0.08476825058460236
# ================================================================================
# Epoch 89 completed
# Average train loss is 0.13095610627062518:
# Average validation loss is 0.2777446689637932
# Average validation dice coef is 0.471917898268313
# ================================================================================
# Epoch:  90 Batch:  0 Current Loss:  0.23678240180015564
# Epoch:  90 Batch:  100 Current Loss:  0.09913895279169083
# ================================================================================
# Epoch 90 completed
# Average train loss is 0.13378646464584626:
# Average validation loss is 0.28311890202599604
# Average validation dice coef is 0.456946163564115
# ================================================================================
# Epoch:  91 Batch:  0 Current Loss:  0.060193777084350586
# Epoch:  91 Batch:  100 Current Loss:  0.09698615968227386
# ================================================================================
# Epoch 91 completed
# Average train loss is 0.14364968931736194:
# Average validation loss is 0.2982767206188795
# Average validation dice coef is 0.43045663672524526
# ================================================================================
# Epoch:  92 Batch:  0 Current Loss:  0.06156636402010918
# Epoch:  92 Batch:  100 Current Loss:  0.09069034457206726
# ================================================================================
# Epoch 92 completed
# Average train loss is 0.1337843653937317:
# Average validation loss is 0.2644494933051032
# Average validation dice coef is 0.4951679642136032
# ================================================================================
# Epoch:  93 Batch:  0 Current Loss:  0.11137466877698898
# Epoch:  93 Batch:  100 Current Loss:  0.06931629776954651
# ================================================================================
# Epoch 93 completed
# Average train loss is 0.11941724160864745:
# Average validation loss is 0.274462523895341
# Average validation dice coef is 0.4789372279837325
# ================================================================================
# Epoch:  94 Batch:  0 Current Loss:  0.09653735905885696
# Epoch:  94 Batch:  100 Current Loss:  0.11065404117107391
# ================================================================================
# Epoch 94 completed
# Average train loss is 0.14269745709655218:
# Average validation loss is 0.2792431718191585
# Average validation dice coef is 0.4662793488115877
# ================================================================================
# Epoch:  95 Batch:  0 Current Loss:  0.14601869881153107
# Epoch:  95 Batch:  100 Current Loss:  0.1525801122188568
# ================================================================================
# Epoch 95 completed
# Average train loss is 0.14259173726178195:
# Average validation loss is 0.2659786349615535
# Average validation dice coef is 0.4974310704179712
# ================================================================================
# Epoch:  96 Batch:  0 Current Loss:  0.2418016642332077
# Epoch:  96 Batch:  100 Current Loss:  0.11283107846975327
# ================================================================================
# Epoch 96 completed
# Average train loss is 0.12797944009150952:
# Average validation loss is 0.29130297959656326
# Average validation dice coef is 0.44240392382080496
# ================================================================================
# Epoch:  97 Batch:  0 Current Loss:  0.1687079668045044
# Epoch:  97 Batch:  100 Current Loss:  0.4983433783054352
# ================================================================================
# Epoch 97 completed
# Average train loss is 0.13401905969040442:
# Average validation loss is 0.29012148021846207
# Average validation dice coef is 0.4451189911043322
# ================================================================================
# Epoch:  98 Batch:  0 Current Loss:  0.21106719970703125
# Epoch:  98 Batch:  100 Current Loss:  0.044055450707674026
# ================================================================================
# Epoch 98 completed
# Average train loss is 0.12512519463182312:
# Average validation loss is 0.2957737140760228
# Average validation dice coef is 0.4366036734065494
# ================================================================================
# Epoch:  99 Batch:  0 Current Loss:  0.12807001173496246
# Epoch:  99 Batch:  100 Current Loss:  0.1770097315311432
# ================================================================================
# Epoch 99 completed
# Average train loss is 0.11904946331904359:
# Average validation loss is 0.2787334455831631
# Average validation dice coef is 0.46753181960131673
# ================================================================================
# Epoch:  100 Batch:  0 Current Loss:  0.12319928407669067
# Epoch:  100 Batch:  100 Current Loss:  0.12660495936870575
# ================================================================================
# Epoch 100 completed
# Average train loss is 0.12349037935778703:
# Average validation loss is 0.27502580007185806
# Average validation dice coef is 0.482875864248018
# ================================================================================
# Highest validation dice score: 0.5027147032119132 at epoch 86

# %%
###load checkpoint

#model.load_state_dict(torch.load("/content/gdrive/MyDrive/Stroke/ehl_epoch15"))

# %%
plt.plot(dice_coeff_focalfn, label = 'Focal')
plt.plot(dice_coeff_dicewithfocal , label = 'Dice with Focal')
plt.plot(dice_coeff_dicefn , label = 'Dice')
plt.legend()
plt.title("dice score of three loss functions")
plt.ylabel("dice score")
plt.xlabel("Epochs")
# Out:
# Text(0.5, 0, 'Epochs')

# %%
with torch.no_grad():
  model.eval()
  for ith_batch, sample_batched in enumerate(validation_loader):
    X_val = sample_batched['image'].to('cuda')
    y_val = sample_batched['gt'].to('cuda')
    y_pred = model(X_val)




    fig = plt.figure()
    fig.add_subplot(1, 3, 1)
    plt.imshow(y_val.cpu()[0,:,:]>0.5,cmap='gray')
    plt.gca().set_title('y_train')
    fig.add_subplot(1, 3, 2)
    plt.imshow(y_pred.cpu()[0,0,:,:]>0.5,cmap='gray')
    plt.gca().set_title('y_pred')
    fig.add_subplot(1, 3, 3)
    plt.imshow((X_val[0,1,:,:].cpu()),cmap='gray')
    plt.gca().set_title('X_val')
    if ith_batch==10:
      break
